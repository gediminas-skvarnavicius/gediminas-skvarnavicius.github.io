# %% [markdown]
# ---
# title: "Analysis of the Football Database"
# format:
#   html:
#     toc: true
#     code-fold: true
#     code-summary: "Show the code"
#     number-depth: 4
#     number-sections: true
# ---

# %% [markdown]
# ## Introduction

# %% [markdown]
# This is the analysis of the [football data set from Kaggle](https://www.kaggle.com/datasets/prajitdatta/ultimate-25k-matches-football-database-european). The aims of this project are to explore the data set and eventually gain insights on potential betting strategies by building models that predict match outcomes.

# %% [markdown]
# ### Imports and Options

# %% [markdown]
# #### Imports

# %%
# %reload_ext autoreload
# %autoreload 1
# Data handling
import duckdb
import pandas as pd
import numpy as np

# Display
from IPython.display import Markdown, display
from tabulate import tabulate

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
from mplsoccer import Pitch

# Statistics
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.miscmodels.ordinal_model import OrderedModel
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, roc_auc_score
from lmfit import Minimizer, Parameters

# Custom
import functions.display_functions as disf
import functions.data_format_functions as dff
from functions.project_functions_classes import Team, MatchPlayers
from functions.project_functions_classes import outcome_guess_prob_dif
from functions.project_functions_classes import outcome_guess_prob_win
from functions.project_functions_classes import classifier_train_prob_win
from functions.project_functions_classes import classifier_train_prob_dif
from functions.project_functions_classes import bet_away, bet_home, bet_tie
# %aimport functions.display_functions
# %aimport functions.project_functions_classes
# %aimport functions.data_format_functions

# %% [markdown]
# #### Options

# %% [markdown]
# ##### Pandas and figure options:

# %%
pd.set_option("mode.chained_assignment", None)
sns.set()
base_fig_width = 8
base_fig_height = 4.5

# %% [markdown]
# ##### DuckDB connection and options:

# %%
con = duckdb.connect()
con.execute(f"INSTALL sqlite")
con.execute(f"LOAD sqlite")
con.execute(f"SET GLOBAL sqlite_all_varchar=true")
con.execute(f"CALL sqlite_attach('data/database.sqlite')")

# %% [markdown]
# ##### Fetching table and column names:

# %%
tables = con.query(
    f"""--sql
SELECT table_name as 'Table Name',
    COUNT(column_name) AS 'Column Count'
FROM information_schema.columns
GROUP BY table_name
"""
).to_df()

table_columns = con.query(
    f"""--sql
SELECT table_name,
    GROUP_CONCAT(column_name) AS column_names
FROM information_schema.columns
GROUP BY table_name"""
).to_df()
tables["column_names"] = table_columns["column_names"].apply(lambda x: x.split(","))

# %% [markdown]
# ##### Significance:

# %%
alpha = 0.95
significance = 1 - alpha

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# The goal of this section is to familiarize with the data set. Some statistical inference is presented here, but the feature selection for ML models are presented in a separate section and mostly relies on their predictive power.

# %% [markdown]
# ### Match

# %% [markdown]
# The data set includes data on more than 25 thousand matches. Outcomes, betting odds, players, teams, and their starting lineup positions are given. This section explores match related portion of the data set.

# %% [markdown]
# ##### Preparing Match data:

# %%
match_cols = tables.loc[tables["Table Name"] == "Match", "column_names"].to_list()[0]
match_cols_to_remove = ["league_id", "stage", "match_api_id", "cross"]
match_cols = [col for col in match_cols if col not in match_cols_to_remove]
match_raw = con.query(
    f"""--sql
          SELECT {', '.join(match_cols)} FROM Match
          """
).to_df()
match_raw.set_index("id", inplace=True)

# %% [markdown]
# #### What in what countries and leagues were the matches played in? By which teams and in which leagues were the most goals scored in?

# %% [markdown]
# <iframe width="850" height="638" src="https://lookerstudio.google.com/embed/reporting/7fdf4aab-2c53-454b-8e7e-adc93591e2dd/page/fsdXD" frameborder="0" style="border:0" allowfullscreen></iframe>

# %% [markdown]
# The Matches were played in 11 different leagues across 11 different European countries. The most goals per match were scored in Netherlands Eredivisie, while the team that scored the most goals per match was FC Barcelona.

# %% [markdown]
# #### Whats the number of matches distribution across the timeline and seasons?

# %% [markdown]
# ##### Preparing the season and date data:

# %%
match_raw["date"] = pd.to_datetime(match_raw["date"])
match_date_count = match_raw.resample("D", on="date").count().cumsum()

seasons = match_raw.groupby("season").agg(
    start=("date", "min"), end=("date", "max"), count=("season", "count")
)
seasons["length"] = seasons["end"] - seasons["start"]

# %% [markdown]
# ##### Plot:

# %%
# | label: fig-match_count
# | fig-cap: The cumulative sum of total matches played are represented by the blue line, the bars in the background indicate the number of matches played that season and its time span.
fig_match_count_date, ax_match_count_date = plt.subplots(
    figsize=(base_fig_width, base_fig_height)
)

ax_match_count_date.plot(match_date_count.index, match_date_count["country_id"])
ax_match_count_date_season = ax_match_count_date.twinx()
ax_match_count_date_season.bar(
    x=seasons["start"],
    height=seasons["count"],
    width=seasons["length"],
    align="edge",
    alpha=0.25,
)
ax_match_count_date.set_ylabel("Total Matches")
ax_match_count_date_season.set_ylabel("Matches by Season")

plt.show()

# %% [markdown]
# Matches are in the data set were played from 2008 to 2016 in 8 seasons.

# %% [markdown]
# #### What is the distribution of goal difference between home and away teams?

# %% [markdown]
# ##### Calculating the goal difference for each mach:

# %%
match_raw[["home_team_goal", "away_team_goal"]] = match_raw[
    ["home_team_goal", "away_team_goal"]
].astype(int)
match_raw["outcome"] = match_raw["home_team_goal"] - match_raw["away_team_goal"]
match_outcomes = match_raw["outcome"].value_counts().to_frame("count")
match_outcomes.reset_index(names=["value"], inplace=True)
match_outcomes["outcome"] = match_outcomes["value"].apply(
    lambda x: "Home Win" if x > 0 else ("Home Loss" if x < 0 else "Tie")
)
match_outcomes["color"] = match_outcomes["value"].apply(
    lambda x: sns.color_palette()[0]
    if x > 0
    else (sns.color_palette()[3] if x < 0 else sns.color_palette()[4])
)

# %% [markdown]
# ##### Plot:

# %%
# | label: fig-match_outcomes
# | fig-cap: The number of matches that ended with a specific goal difference.
fig_match_outcomes, ax_match_outcomes = plt.subplots(
    figsize=(base_fig_width, base_fig_height)
)
ax_match_outcomes.bar(
    match_outcomes["value"],
    match_outcomes["count"],
    label=match_outcomes["outcome"],
    color=match_outcomes["color"],
    align="center",
)
handles, labels = ax_match_outcomes.get_legend_handles_labels()
ax_match_outcomes.legend(handles[:3], labels[:3])
ax_match_outcomes.set(xticks=np.arange(start=-8, stop=12, step=2))
ax_match_outcomes.set_ylabel("Number of Matches")
ax_match_outcomes.set_xlabel("Goal Difference")
plt.show()

# %% [markdown]
# Visual inspection of the match outcome data suggests that there might be a home advantage. Another important observation is that a large portion of matches end in ties.

# %% [markdown]
# #### Is there a home advantage?

# %% [markdown]
# ##### Chi square test of non-tie matches with the null hypothesis being that there is an equal amount of home wins and away wins:

# %%
total_home_wins = match_outcomes.loc[
    match_outcomes["outcome"] == "Home Win", "count"
].sum()
total_away_wins = match_outcomes.loc[
    match_outcomes["outcome"] == "Home Loss", "count"
].sum()
home_advantage_result = stats.chisquare([total_home_wins, total_away_wins])

# %% [markdown]
# ##### Results:

# %%
Markdown(
    f"""
Based on a chi-square test with a confidence level of 95%, the p-value of {home_advantage_result.pvalue:.2e}
strongly suggests that there is a significant home advantage.
{total_home_wins} of all non-tie wins were by the home team,
while only {total_away_wins} matches were won by away teams.
"""
)
# Out:
# Based on a chi-square test with a confidence level of 95%, the p-value of 2.82e-224
# strongly suggests that there is a significant home advantage.
# 11917 of all non-tie wins were by the home team,
# while only 7466 matches were won by away teams.

# %% [markdown]
# #### What are the different player combinations used?

# %% [markdown]
# The data set includes starting lineup positions on the field.

# %% [markdown]
# ##### Preparing player position combination columns:

# %%
# Getting lists of position column names
home_x_cols = [x for x in match_raw.columns.to_list() if "home_player_X" in x]
home_y_cols = [x for x in match_raw.columns.to_list() if "home_player_Y" in x]
away_x_cols = [x for x in match_raw.columns.to_list() if "away_player_X" in x]
away_y_cols = [x for x in match_raw.columns.to_list() if "away_player_Y" in x]

# Changing  the data type to numeric
match_raw[home_x_cols + home_y_cols + away_x_cols + away_y_cols] = match_raw[
    home_x_cols + home_y_cols + away_x_cols + away_y_cols
].apply(pd.to_numeric)

# Putting the home player coordinates into frozensets of (x,y) tuples
match_raw["combinations_home"] = match_raw.apply(
    lambda row: frozenset([(x, y) for x, y in zip(row[home_x_cols], row[home_y_cols])]),
    axis=1,
)

# Changing any values that contain at least a single NaN value to Nan
match_raw["combinations_home"] = match_raw["combinations_home"].apply(
    lambda x: np.nan if any(np.isnan(y) for tup in x for y in tup) else x
)

# Removing frozensets with less than 11 player coordinates
match_raw["combinations_home"] = match_raw["combinations_home"].apply(
    lambda x: x if type(x) == frozenset and len(x) == 11 else np.nan
)

# Putting the away player coordinates into frozensets of (x,y) tuples
match_raw["combinations_away"] = match_raw.apply(
    lambda row: frozenset([(x, y) for x, y in zip(row[away_x_cols], row[away_y_cols])]),
    axis=1,
)

# Removing frozensets with less than 11 player coordinates
match_raw["combinations_away"] = match_raw["combinations_away"].apply(
    lambda x: np.nan if any(np.isnan(y) for tup in x for y in tup) else x
)

# Putting the away player coordinates into frozensets of (x,y) tuples
match_raw["combinations_away"] = match_raw["combinations_away"].apply(
    lambda x: x if type(x) == frozenset and len(x) == 11 else np.nan
)

# %% [markdown]
# ##### Number of different 11 player combinations:

# %%
unique_combos = (
    pd.concat([match_raw["combinations_home"], match_raw["combinations_away"]])
    .value_counts()
    .to_frame(name="count")
    .reset_index(names=["combo"])
)
len(unique_combos)
# Out:
# 37

# %% [markdown]
# ##### Combination distribution on the pitch:

# %%
# | label: fig-pitch
# | fig-cap: The four most popular starting lineup position combinations.

# Correcting the position of the goal keeper
unique_combos["scaled_combo"] = unique_combos["combo"].apply(
    lambda x: frozenset((5, 1) if t == (1, 1) else t for t in x)
)

# Scaling to the pitch plot
pitch_y_offset = 4 - dff.scale_num(1, 1, 11, -4, 80)
unique_combos["scaled_combo"] = unique_combos["scaled_combo"].apply(
    lambda x: frozenset(
        (
            dff.scale_num(t[0], 1, 11, 0, 80) + pitch_y_offset,
            dff.scale_num(t[1], 1, 11, 0, 100),
        )
        for t in x
    )
)

pitch = Pitch(
    pitch_color="grass",
    line_color="white",
    stripe=True,
)

fig_pitch, ax_pitch = pitch.draw(
    nrows=2, ncols=2, figsize=(base_fig_width, base_fig_height)
)
ax_pitch = ax_pitch.flatten()

for i, combo in enumerate(unique_combos[:4].iterrows()):
    for pos in combo[1]["scaled_combo"]:
        ax_pitch[i].scatter(
            pos[1],
            pos[0],
            s=50,
            color=sns.color_palette("deep")[0],
        )
plt.tight_layout(w_pad=-6)
plt.show()

# %% [markdown]
# ### Player attributes

# %% [markdown]
# The dataset included a variety of numerical and categorical player attributes, this section presents this portion of the data.

# %% [markdown]
# #### What is the player rating and potential distribution?

# %%
# | label: fig-player_rating_hist
# | fig-cap: The distribution of player overall rating and potential. The latest stats of each player is included in this figure.

# Fetching player attributes with the latest date.
rating_potential = con.query(
    """--sql
SELECT overall_rating,
    potential
FROM Player_Attributes p
    JOIN(
        SELECT player_api_id,
            MAX(date) AS max_date
        FROM Player_attributes
        GROUP BY player_api_id
    ) sub ON p.player_api_id = sub.player_api_id
    AND p.date = sub.max_date """
).to_df()
rating_potential.dropna(inplace=True)
rating_potential = rating_potential.astype(int)

# Plot
fig_player_rating_hist, (
    ax_player_rating_hist,
    ax_player_potential_hist,
) = plt.subplots(1, 2, figsize=(base_fig_width, base_fig_height))

rating_potential.hist("potential", ax=ax_player_potential_hist)
rating_potential.hist("overall_rating", ax=ax_player_rating_hist)
disf.axis_titles(ax_player_potential_hist, xtitle="Player Potential", ytitle="Count")
disf.axis_titles(ax_player_rating_hist, xtitle="Player Overall Rating", ytitle="Count")
plt.show()

# %% [markdown]
# #### Whats is the foot preference distribution?

# %%
con.query(
    f"""--sql
SELECT 
    COUNT(*) AS total,
    SUM(CASE WHEN preferred_foot = 'right' THEN 1 ELSE 0 END) AS right_count,
    SUM(CASE WHEN preferred_foot = 'left' THEN 1 ELSE 0 END) AS left_count
FROM Player_Attributes p
    JOIN(
        SELECT player_api_id,
            MAX(date) AS max_date
        FROM Player_attributes
        GROUP BY player_api_id
    ) sub ON p.player_api_id = sub.player_api_id
    AND p.date = sub.max_date"""
).to_df().astype(int).rename(
    columns={
        "total": "Total",
        "right_count": "Right footed players",
        "left_count": "Left footed players",
    }
)
# Out:
#    Total  Right footed players  Left footed players
# 0  11064                  8373                 2687

# %% [markdown]
# #### Do right and left footed players have a different overall rating?

# %% [markdown]
# ##### Fetching the data:

# %%
player_f_rating = con.query(
    f"""--sql
SELECT  CAST(overall_rating as INT) AS 'Overall Rating', preferred_foot
FROM Player_Attributes p
    JOIN(
        SELECT player_api_id,
            MAX(date) AS max_date
        FROM Player_attributes
        GROUP BY player_api_id
    ) sub ON p.player_api_id = sub.player_api_id
    AND p.date = sub.max_date"""
).to_df()

# %% [markdown]
# ##### T-test:

# %%
player_f_rating_levresults = stats.levene(
    player_f_rating.loc[player_f_rating["preferred_foot"] == "right", "Overall Rating"],
    player_f_rating.loc[player_f_rating["preferred_foot"] == "left", "Overall Rating"],
)

player_f_rating_tresults = stats.ttest_ind(
    player_f_rating.loc[player_f_rating["preferred_foot"] == "right", "Overall Rating"],
    player_f_rating.loc[player_f_rating["preferred_foot"] == "left", "Overall Rating"],
    equal_var=player_f_rating_levresults.pvalue > significance,
)
Markdown(
    f"""t-statistic: {round(player_f_rating_tresults.statistic,2)}<br>
         p-val: {round(player_f_rating_tresults.pvalue,2)}<br>
         There {'is a' if player_f_rating_tresults.pvalue < significance else 'is no'} 
         significant difference in overall rating between right and left footed players
         """
)
# Out:
# t-statistic: -0.54<br>
#          p-val: 0.59<br>
#          There is no
#          significant difference in overall rating between right and left footed players

# %% [markdown]
# #### What is the distribution of goal keeper attributes?

# %% [markdown]
# ##### Getting the histogram data for goal keeper diving ability:

# %%
goaly_hist_df = (
    con.query(
        f"""--sql
WITH bin_stats AS (
    SELECT (
            (
                MAX(CAST(gk_diving AS INT)) - MIN(CAST(gk_diving AS INT))
            ) / 10
        ) AS bin_size
    FROM Player_Attributes p
        JOIN(
            SELECT player_api_id,
                MAX(date) AS max_date
            FROM Player_attributes
            GROUP BY player_api_id
        ) sub ON p.player_api_id = sub.player_api_id
        AND p.date = sub.max_date
)
SELECT FLOOR(
        CAST(gk_diving AS INT) / (
            SELECT bin_size
            FROM bin_stats
        )
    ) * (
        SELECT bin_size
        FROM bin_stats
    ) AS bin,
    COUNT(*) AS count
FROM Player_Attributes p
    JOIN(
        SELECT player_api_id,
            MAX(date) AS max_date
        FROM Player_attributes
        GROUP BY player_api_id
    ) sub ON p.player_api_id = sub.player_api_id
    AND p.date = sub.max_date
GROUP BY bin
ORDER BY bin;
    """
    )
    .to_df()
    .astype(int, errors="ignore")
)

# %% [markdown]
# ##### Plotting the frequencies:

# %%
# | label: fig-goaly_stats
# | fig-cap: The distribution of "Goal keeper diving rating across all players in the data set. The latest entry for each player is taken."

fig_goaly_stats, ax_goaly_stats = plt.subplots()
sns.barplot(
    goaly_hist_df, x="bin", y="count", ax=ax_goaly_stats, color=sns.color_palette()[0]
)
ax_goaly_stats.set_xticks(np.arange(0, 10, step=2))
ax_goaly_stats.set_xticklabels(
    np.linspace(goaly_hist_df["bin"].min(), goaly_hist_df["bin"].max(), num=5).astype(
        int
    )
)
ax_goaly_stats.set_yscale("log")
disf.axis_titles(ax=ax_goaly_stats, ytitle="Count", xtitle="Goal Keeper Diving Rating")
plt.show()

# %% [markdown]
# The distribution of goalkeeper attributes indicate that there is a split between goalkeepers and regular players.

# %% [markdown]
# #### Is there a linear correlation between player overall ratings and their other attributes?

# %% [markdown]
# ##### Importing all player attributes:

# %%
player_attr_raw = con.query(
    f"""--sql
SELECT * FROM Player_Attributes
"""
).to_df()
player_attr_numeric = [
    "overall_rating",
    "potential",
    "crossing",
    "finishing",
    "heading_accuracy",
    "short_passing",
    "volleys",
    "dribbling",
    "curve",
    "free_kick_accuracy",
    "long_passing",
    "ball_control",
    "acceleration",
    "sprint_speed",
    "agility",
    "reactions",
    "balance",
    "shot_power",
    "jumping",
    "stamina",
    "strength",
    "long_shots",
    "aggression",
    "interceptions",
    "positioning",
    "vision",
    "penalties",
    "marking",
    "standing_tackle",
    "sliding_tackle",
    "gk_diving",
    "gk_handling",
    "gk_kicking",
    "gk_positioning",
    "gk_reflexes",
]
player_attr_raw[player_attr_numeric] = player_attr_raw[player_attr_numeric].apply(
    pd.to_numeric
)
player_attr_raw["date"] = pd.to_datetime(player_attr_raw["date"])

# %% [markdown]
# ##### Calculating and displaying the correlations:

# %%
# | label: tbl-rating_att_corr
# | tbl-cap: Pearson's r of overall rating versus other player attributes calculated for all players and goalkeepers separately. The goalkeepers here are defined as having goal keeper diving attribute higher than 50.

player_att_corrs = (
    player_attr_raw[player_attr_numeric]
    .corr()["overall_rating"]
    .to_frame()
    .join(
        player_attr_raw[player_attr_numeric]
        .loc[player_attr_raw[player_attr_numeric]["gk_diving"] > 50]
        .corr()["overall_rating"]
        .to_frame(),
        rsuffix="_goal_keeper",
    )
)


player_att_corrs.style.background_gradient("coolwarm").format("{:.2f}")
# Out:
# <style type="text/css">
# #T_e643b_row0_col0, #T_e643b_row0_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e643b_row1_col0, #T_e643b_row15_col0 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_e643b_row1_col1 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_e643b_row2_col0, #T_e643b_row8_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_e643b_row2_col1, #T_e643b_row3_col1, #T_e643b_row29_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e643b_row3_col0, #T_e643b_row19_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_e643b_row4_col0, #T_e643b_row20_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_e643b_row4_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e643b_row5_col0 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_e643b_row5_col1, #T_e643b_row28_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e643b_row6_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_e643b_row6_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_e643b_row7_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e643b_row7_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e643b_row8_col1, #T_e643b_row21_col1, #T_e643b_row32_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_e643b_row9_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e643b_row9_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e643b_row10_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_e643b_row10_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_e643b_row11_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_e643b_row11_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e643b_row12_col0, #T_e643b_row12_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e643b_row13_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e643b_row13_col1 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_e643b_row14_col0, #T_e643b_row14_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e643b_row15_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_e643b_row16_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e643b_row16_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_e643b_row17_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_e643b_row17_col1, #T_e643b_row29_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_e643b_row18_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_e643b_row18_col1, #T_e643b_row25_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_e643b_row19_col1, #T_e643b_row27_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_e643b_row20_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_e643b_row21_col0, #T_e643b_row26_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_e643b_row22_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_e643b_row22_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e643b_row23_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e643b_row23_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_e643b_row24_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_e643b_row24_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e643b_row25_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e643b_row26_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_e643b_row27_col1, #T_e643b_row28_col1, #T_e643b_row31_col0, #T_e643b_row33_col0, #T_e643b_row34_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e643b_row30_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e643b_row30_col1 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_e643b_row31_col1 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_e643b_row32_col1 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_e643b_row33_col1 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_e643b_row34_col1 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e643b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e643b_level0_col0" class="col_heading level0 col0" >overall_rating</th>
#       <th id="T_e643b_level0_col1" class="col_heading level0 col1" >overall_rating_goal_keeper</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e643b_level0_row0" class="row_heading level0 row0" >overall_rating</th>
#       <td id="T_e643b_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_e643b_row0_col1" class="data row0 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row1" class="row_heading level0 row1" >potential</th>
#       <td id="T_e643b_row1_col0" class="data row1 col0" >0.77</td>
#       <td id="T_e643b_row1_col1" class="data row1 col1" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row2" class="row_heading level0 row2" >crossing</th>
#       <td id="T_e643b_row2_col0" class="data row2 col0" >0.36</td>
#       <td id="T_e643b_row2_col1" class="data row2 col1" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row3" class="row_heading level0 row3" >finishing</th>
#       <td id="T_e643b_row3_col0" class="data row3 col0" >0.33</td>
#       <td id="T_e643b_row3_col1" class="data row3 col1" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row4" class="row_heading level0 row4" >heading_accuracy</th>
#       <td id="T_e643b_row4_col0" class="data row4 col0" >0.31</td>
#       <td id="T_e643b_row4_col1" class="data row4 col1" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row5" class="row_heading level0 row5" >short_passing</th>
#       <td id="T_e643b_row5_col0" class="data row5 col0" >0.46</td>
#       <td id="T_e643b_row5_col1" class="data row5 col1" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row6" class="row_heading level0 row6" >volleys</th>
#       <td id="T_e643b_row6_col0" class="data row6 col0" >0.36</td>
#       <td id="T_e643b_row6_col1" class="data row6 col1" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row7" class="row_heading level0 row7" >dribbling</th>
#       <td id="T_e643b_row7_col0" class="data row7 col0" >0.35</td>
#       <td id="T_e643b_row7_col1" class="data row7 col1" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row8" class="row_heading level0 row8" >curve</th>
#       <td id="T_e643b_row8_col0" class="data row8 col0" >0.36</td>
#       <td id="T_e643b_row8_col1" class="data row8 col1" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row9" class="row_heading level0 row9" >free_kick_accuracy</th>
#       <td id="T_e643b_row9_col0" class="data row9 col0" >0.35</td>
#       <td id="T_e643b_row9_col1" class="data row9 col1" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row10" class="row_heading level0 row10" >long_passing</th>
#       <td id="T_e643b_row10_col0" class="data row10 col0" >0.44</td>
#       <td id="T_e643b_row10_col1" class="data row10 col1" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row11" class="row_heading level0 row11" >ball_control</th>
#       <td id="T_e643b_row11_col0" class="data row11 col0" >0.44</td>
#       <td id="T_e643b_row11_col1" class="data row11 col1" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row12" class="row_heading level0 row12" >acceleration</th>
#       <td id="T_e643b_row12_col0" class="data row12 col0" >0.25</td>
#       <td id="T_e643b_row12_col1" class="data row12 col1" >0.21</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row13" class="row_heading level0 row13" >sprint_speed</th>
#       <td id="T_e643b_row13_col0" class="data row13 col0" >0.25</td>
#       <td id="T_e643b_row13_col1" class="data row13 col1" >0.23</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row14" class="row_heading level0 row14" >agility</th>
#       <td id="T_e643b_row14_col0" class="data row14 col0" >0.24</td>
#       <td id="T_e643b_row14_col1" class="data row14 col1" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_e643b_level0_row15" class="row_heading level0 row15" >reactions</th>
#       <td id="T_

# %% [markdown]
# As seen in table @tbl-rating_att_corr, For all players there are moderate linear correlations between player overall ratings and all attributes except those related to goal keeping. It is the opposite for dedicated goalkeepers.

# %% [markdown]
# #### Whats the distribution of attacking and defensive work?

# %% [markdown]
# ##### Fetching the data:

# %%
att_def_df = con.query(
    f"""--sql
SELECT attacking_work_rate, defensive_work_rate
FROM Player_Attributes p
    JOIN(
        SELECT player_api_id,
            MAX(date) AS max_date
        FROM Player_attributes
        GROUP BY player_api_id
    ) sub ON p.player_api_id = sub.player_api_id
    AND p.date = sub.max_date"""
).to_df()

# %% [markdown]
# ##### Plot:

# %%
# | label: fig-att_def
# | fig-cap: A heatmap of defensive and attacking work rate of all players. The latest entries for each player were taken.

fig_att_def, ax_att_def = plt.subplots(figsize=(base_fig_width, base_fig_height))
sns.heatmap(
    pd.crosstab(att_def_df["attacking_work_rate"], att_def_df["defensive_work_rate"])[
        ["high", "medium", "low"]
    ].loc[["high", "medium", "low"]],
    annot=True,
    fmt=".0f",
    ax=ax_att_def,
)
disf.axis_titles(
    ax=ax_att_def, xtitle="Defensive Work Rate", ytitle="Attacking Work Rate"
)

# %% [markdown]
# The majority of players have both medium attacking and defensive work rates.

# %% [markdown]
# ### Team Attributes

# %% [markdown]
# This section explores the attributes of individual teams that were given in the data set.

# %% [markdown]
# ##### Fetching the team attributes:

# %%
team_attr_raw = con.query(
    f"""--sql
SELECT *
FROM Team_Attributes
"""
).to_df()

# %% [markdown]
# #### What is the distribution of Team attributes?

# %% [markdown]
# ##### Making a list of numeric attributes and fixing data types:

# %%
team_numeric_cols = [
    "buildUpPlaySpeed",
    "buildUpPlayDribbling",
    "buildUpPlayPassing",
    "chanceCreationPassing",
    "chanceCreationCrossing",
    "chanceCreationShooting",
    "defencePressure",
    "defenceAggression",
    "defenceTeamWidth",
]
team_categoric_cols = [col + "Class" for col in team_numeric_cols]
team_attr_raw[team_numeric_cols] = team_attr_raw[team_numeric_cols].apply(
    pd.to_numeric, errors="coerce"
)
team_attr_raw["date"] = pd.to_datetime(team_attr_raw["date"])
team_attr_raw.set_index("id", inplace=True)

latest_team_attr = team_attr_raw.loc[team_attr_raw.groupby("team_api_id").date.idxmax()]

# %% [markdown]
# ##### Plotting numeric attributes and their categories:

# %%
# | label: fig-team_attr
# | fig-cap: Histograms of numeric team attributes. Categories for the same characteristics are also given in the data set, therefore the histograms are split according to those categories.

fig_team_attr, ax_team_attr = plt.subplots(
    5, 2, figsize=(base_fig_width, base_fig_height * 4)
)
ax_team_attr = ax_team_attr.flatten()
for i, attr in enumerate(team_numeric_cols):
    sns.histplot(latest_team_attr, x=attr, hue=attr + "Class", ax=ax_team_attr[i])
    ax_team_attr[i].get_legend().set_title("")

fig_team_attr.delaxes(ax_team_attr[-1])
plt.tight_layout(h_pad=2)
plt.show()

# %% [markdown]
# ##### Plotting non numeric attributes:

# %%
# | label: fig-team_attr_cat
# | fig-cap: The distribution of categorical attributes amongst teams.
team_attr_non_numeric = [
    "buildUpPlayPositioningClass",
    "chanceCreationPositioningClass",
    "defenceDefenderLineClass",
]

fig_team_attr_cat, ax_team_attr_cat = plt.subplots(
    1, 3, figsize=(base_fig_width, base_fig_height)
)
ax_team_attr_cat = ax_team_attr_cat.flatten()

for i, attr in enumerate(team_attr_non_numeric):
    sns.countplot(data=latest_team_attr, x=attr, ax=ax_team_attr_cat[i])
    ax_team_attr_cat[i].set_xlabel(attr[:-5])
plt.tight_layout(w_pad=3)
plt.show()

# %% [markdown]
# Team attributes that can be described numerically are given in both numeric and three-category formats as can be seen in @fig-team_attr. Three boolean attributes were also given as seen in @fig-team_attr_cat.

# %% [markdown]
# #### Do the numeric team attributes correlate linearly with each other?

# %%
disf.get_correlation_pairs(latest_team_attr, 0.3, -0.3).rename(
    {"r-value": "Pearson's r", "feature_pair": "Feature pair"}, axis=1
)
# Out:
#    Pearson's r                               Feature pair
# 0     0.327754  (chanceCreationPassing, buildUpPlaySpeed)
# 2     0.466181       (defencePressure, defenceAggression)
# 3     0.363279        (defenceTeamWidth, defencePressure)

# %% [markdown]
# Certain defensive attributes seem to have a moderate linear correlation with each other, as well as build up play speed and chance creation passing attributes.

# %% [markdown]
# ## Feature selection

# %% [markdown]
# This section delves into the feature selection process for the final logistic regression model, aimed at predicting whether the home team wins the match. The primary focus of the model lies in achieving high predictive power. As a result, the feature selection heavily relies on the predictive capabilities of different feature sets.

# %% [markdown]
# ### Starting line-up combinations

# %% [markdown]
# Making a copy the match DataFrame with only relevant information:

# %%
match_win_df = match_raw[
    [
        "country_id",
        "date",
        "home_team_api_id",
        "away_team_api_id",
        "home_team_goal",
        "away_team_goal",
    ]
]

match_win_df["home_team_win"] = match_win_df.apply(
    lambda x: 1 if x["home_team_goal"] > x["away_team_goal"] else 0, axis=1
)

# %% [markdown]
# #### Do combinations influence the match outcome?

# %% [markdown]
# ##### Adding the combination data:

# %%
# Number labels for unique combinations
combo_dict = unique_combos["combo"].to_dict()
combo_dict = {v: k for k, v in combo_dict.items()}

# Adding the combinations from the raw data
match_win_df_combo = pd.merge(
    match_win_df,
    match_raw[["combinations_home", "combinations_away"]],
    left_index=True,
    right_index=True,
)

# Changing the combinations into a single number label
match_win_df_combo[["combinations_home", "combinations_away"]] = match_win_df_combo[
    ["combinations_home", "combinations_away"]
].replace(combo_dict)

# Making a column with the home away combination pairs
match_win_df_combo["combo_home_away"] = match_win_df_combo.apply(
    lambda x: (x["combinations_home"], x["combinations_away"]), axis=1
)
match_win_df_combo["combo_home_away"] = match_win_df_combo["combo_home_away"].apply(
    lambda x: np.nan if np.isnan(x).any() else x
)

# %% [markdown]
# ##### Chi-squared test with the null hypothesis that home team combination (top 5 combinations only) is not associated to home the home team winning:

# %%
comb_h_home_w_con_tab = pd.crosstab(
    match_win_df_combo.loc[
        match_win_df_combo["combinations_home"] <= 5, "home_team_win"
    ],
    match_win_df_combo.loc[
        match_win_df_combo["combinations_home"] <= 5, "combinations_home"
    ],
)
comb_h_home_w_results = stats.chi2_contingency(comb_h_home_w_con_tab)
Markdown(
    f"""Chi-squared statistic: {round(comb_h_home_w_results.statistic,1)}<br>
         p-value: {comb_h_home_w_results.pvalue:.2e}<br>
         The home team combination {'is' if comb_h_home_w_results.pvalue<significance else 'is not'} 
         significantly associated with the home team winning.
         """
)
# Out:
# Chi-squared statistic: 50.8<br>
#          p-value: 9.40e-10<br>
#          The home team combination is
#          significantly associated with the home team winning.

# %% [markdown]
# ##### Chi-squared test with the null hypothesis that away team combination (top 5 combinations only) is not associated to home the home team winning:

# %%
comb_a_home_w_con_tab = pd.crosstab(
    match_win_df_combo.loc[
        match_win_df_combo["combinations_away"] <= 5, "home_team_win"
    ],
    match_win_df_combo.loc[
        match_win_df_combo["combinations_away"] <= 5, "combinations_away"
    ],
)
comb_a_home_w_results = stats.chi2_contingency(comb_a_home_w_con_tab)

Markdown(
    f"""Chi-squared statistic: {round(comb_a_home_w_results.statistic,1)}<br>
         p-value: {comb_a_home_w_results.pvalue:.2e}<br>
         The home team combination 
         {'is' if comb_a_home_w_results.pvalue < significance else 'is not'} 
         significantly associated with the home team winning.
         """
)
# Out:
# Chi-squared statistic: 27.1<br>
#          p-value: 5.55e-05<br>
#          The home team combination
#          is
#          significantly associated with the home team winning.

# %% [markdown]
# ##### Chi-squared test with the null hypothesis that home-away team combination pair is not associated to home the home team winning:

# %%
comb_ha_home_w_con_tab = pd.crosstab(
    match_win_df_combo["combo_home_away"].apply(str),
    match_win_df_combo["home_team_win"],
)
comb_ha_home_w_results = stats.chi2_contingency(comb_ha_home_w_con_tab)

Markdown(
    f"""Chi-squared statistic: {round(comb_ha_home_w_results.statistic,1)}<br>
         p-value: {comb_ha_home_w_results.pvalue:.2e}<br>
         The home-away team combination pair 
         {'is' if comb_ha_home_w_results.pvalue<significance else 'is not'} 
         significantly associated with the home team winning.
         """
)
# Out:
# Chi-squared statistic: 756.2<br>
#          p-value: 3.67e-05<br>
#          The home-away team combination pair
#          is
#          significantly associated with the home team winning.

# %% [markdown]
# ##### Home team combination-match outcome heatmap:

# %%
# | label: fig-combo_heatmap
# | fig-cap: Heatmap of six most popular home team starting lineup combinations versus match outcome.

fig_combo_contingency, ax_combo_contingency = plt.subplots(
    figsize=(base_fig_width, base_fig_height)
)
sns.heatmap(
    comb_h_home_w_con_tab.apply(lambda x: x.div(x.sum(), axis=0)),
    fmt=".0%",
    annot=True,
    ax=ax_combo_contingency,
)
disf.axis_titles(
    ax=ax_combo_contingency, xtitle="Home Team Combination", ytitle="Home Team Win"
)

ax_combo_contingency.set_xticklabels(np.arange(0, 6))
ax_combo_contingency.set_yticklabels(["Loss/Tie", "Win"])
plt.show()

# %% [markdown]
# From the statistical analysis we can say that the starting lineup combinations do influence the match outcome. An example of this is illustrated in @fig-combo_heatmap, where it can be seen that certain combinations such as combination 2 have a higher win percentage than others such as combination 5.

# %% [markdown]
# #### Can the combinations be used to predict match outcome?

# %% [markdown]
# Due to the categoric nature of the combination data and the number of different categories the random forest model was chosen to test the predictive power of this feature set. The Model is built by using both home team and away team starting lineup combinations.

# %% [markdown]
# ##### Building the random forest model and making predictions:

# %%
match_win_df_combo.dropna(inplace=True)
home_win_target = match_win_df_combo["home_team_win"]
home_win_team_features = match_win_df_combo[["combinations_home", "combinations_away"]]
# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    home_win_team_features, home_win_target, test_size=0.33, random_state=1
)

# Create and fit the logistic regression model
logit_model = RandomForestClassifier()
result = logit_model.fit(X_train, y_train)

# Predict using the trained model
predictions = result.predict(X_test)

# %% [markdown]
# ##### Classification report:

# %%
print(classification_report(y_test, predictions.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.81      0.66      4360
#            1       0.48      0.21      0.29      3607
#
#     accuracy                           0.54      7967
#    macro avg       0.52      0.51      0.47      7967
# weighted avg       0.52      0.54      0.49      7967

# %% [markdown]
# ##### Outcome skew in the test set:

# %%
y_test.value_counts(normalize=True).to_frame(name="Fraction")
# Out:
#    Fraction
# 0  0.547257
# 1  0.452743

# %% [markdown]
# ##### Receiver operating characteristic curve:

# %%
# | label: fig-combo_roc
# | fig-cap: Receiver operating characteristic curve of the home-win predictions made by the random forest model trained on team starting lineup combinations.

fpr, tpr, thresholds = roc_curve(y_test, predictions)
auc_score = roc_auc_score(y_test, predictions)

fig_combo_roc, ax_combo_roc = plt.subplots(figsize=(base_fig_width, base_fig_height))
ax_combo_roc.plot(fpr, tpr, label="ROC curve (AUC = %0.2f)" % auc_score)
ax_combo_roc.plot([0, 1], [0, 1], "k--")  # Random guessing line
ax_combo_roc.set_xlabel("False Positive Rate")
ax_combo_roc.set_ylabel("True Positive Rate")
ax_combo_roc.legend(loc="lower right")
plt.show()

# %% [markdown]
# The random forest model based on the home team and away team starting line-up combinations predicted the game outcome with 54% accuracy. This value does not be the underlying outcome data skew and barely beats random guessing as seen from the ROC curve (@fig-combo_roc) therefore these features are not included in the final model.

# %% [markdown]
# ### Team Attributes

# %% [markdown]
# #### Preparing the features

# %% [markdown]
# In the dataset, team attributes have undergone multiple updates over time, likely derived from the respective teams' performances in various matches, possibly even including the matches contained within this dataset. Consequently, we must exercise caution not to incorporate attributes updated after each match occurrence, as doing so could introduce match outcome leakage into our feature set, which can significantly bias the model and compromise its ability to generalize to new, unseen data. To ensure the integrity and validity of our predictive model, we must strictly adhere to using only those team attributes that were available up until the time of each match without incorporating any post-match updates.

# %% [markdown]
# ##### Importing team attributes into a dataframe:

# %%
team_attr_raw = con.query(
    """--sql
SELECT *
FROM Team_attributes
"""
).to_df()

team_attr_raw["date"] = pd.to_datetime(team_attr_raw["date"])
team_attr_raw[team_numeric_cols] = team_attr_raw[team_numeric_cols].apply(pd.to_numeric)

# %% [markdown]
# ##### Creating Team class objects for each team:

# %%
unique_team_ids = [
    i[0]
    for i in con.query(
        """--sql
SELECT DISTINCT team_api_id
FROM Team_attributes
"""
    ).fetchall()
]
teams = {}

for team in unique_team_ids:
    teams[team] = Team(team)
    teams[team].get_data(team_attr_raw)

# %% [markdown]
# ##### Removing matches with teams that have no attributes:

# %%
match_win_df_team = match_win_df[
    match_win_df.index.isin(match_win_df_combo.index)
]  # not using rows with missing combination data
match_win_df_team = match_win_df[
    ~match_win_df["away_team_api_id"].isin(
        set(unique_team_ids).symmetric_difference(
            match_win_df["away_team_api_id"].unique()
        )
    )
]

match_win_df_team = match_win_df_team[
    ~match_win_df_team["home_team_api_id"].isin(
        set(unique_team_ids).symmetric_difference(
            match_win_df_team["home_team_api_id"].unique()
        )
    )
]

# %% [markdown]
# ##### Getting the latest team attributes by match date using the Team class:

# %%
team_attributes_home = {}
for index in match_win_df_team.index:
    team_attributes_home[index] = teams[
        match_win_df_team.at[index, "home_team_api_id"]
    ].get_latest_entry(match_win_df_team.loc[index, "date"], team_numeric_cols)

team_attributes_away = {}
for index in match_win_df_team.index:
    team_attributes_away[index] = teams[
        match_win_df_team.at[index, "away_team_api_id"]
    ].get_latest_entry(match_win_df_team.loc[index, "date"], team_numeric_cols)

match_win_df_team = match_win_df_team.join(
    pd.concat(
        list(team_attributes_home.values()), keys=team_attributes_home.keys()
    ).droplevel(1),
    rsuffix="_home",
)

match_win_df_team = match_win_df_team.join(
    pd.concat(
        list(team_attributes_away.values()), keys=team_attributes_away.keys()
    ).droplevel(1),
    rsuffix="_away",
)

# %% [markdown]
# ##### Dropping matches where teams do not have date relevant attributes:

# %%
match_win_df_team.dropna(inplace=True)

# %% [markdown]
# ##### Number of matches left:

# %%
len(match_win_df_team)
# Out:
# 5562

# %% [markdown]
# ##### Lineup combination summary

# %% [markdown]
# A custom class object called "Team" has been developed, wherein a new instance of the Team class is created for each team in the dataset. This class effectively stores all attribute entries associated with a specific team. Additionally, the class includes a method that, given a specific date and a list of columns, enables retrieval of the latest features that were entered before the specified date.
#
# Using this Team class, relevant date-specific attributes for both the home and away teams were incorporated for each match in the dataset. However, Only five and a half thousand matches out of the total dataset had date-relevant team attributes.

# %% [markdown]
# #### Logistic regression with all home and away team attributes

# %% [markdown]
# ##### Model training and prediction:

# %%
cols_to_drop = [
    "date",
    "country_id",
    "home_team_api_id",
    "away_team_api_id",
    "home_team_goal",
    "away_team_goal",
    "home_team_win",
]

home_win_target_team = match_win_df_team["home_team_win"]
home_win_team_features = match_win_df_team.drop(columns=cols_to_drop)

# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    home_win_team_features, home_win_target_team, test_size=0.33, random_state=1
)

# Scaling the data
team_feat_scaler = StandardScaler()
X_train = team_feat_scaler.fit_transform(X_train)
X_test = team_feat_scaler.fit_transform(X_test)

# Create and fit the logistic regression model
logit_model_team_raw = sm.Logit(y_train, sm.add_constant(X_train))
result_team_raw = logit_model_team_raw.fit()

# Predict using the trained model
predictions_team_raw = result_team_raw.predict(sm.add_constant(X_test))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.670147
#          Iterations 4

# %% [markdown]
# #### Classification report:

# %%
print(classification_report(y_test, predictions_team_raw.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.78      0.67      1010
#            1       0.55      0.33      0.41       826
#
#     accuracy                           0.58      1836
#    macro avg       0.57      0.56      0.54      1836
# weighted avg       0.57      0.58      0.56      1836

# %% [markdown]
# ##### Test set outcome skew:

# %%
y_test.value_counts(normalize=True).to_frame(name="Fraction")
# Out:
#    Fraction
# 0  0.550109
# 1  0.449891

# %%
# | label: fig-roc_team_all
# | fig-cap: Receiver operating characteristic curve of the home-win predictions made by a logistic regression model trained on all unmodified team attributes.

fpr, tpr, thresholds = roc_curve(y_test, predictions_team_raw)
auc_score = roc_auc_score(y_test, predictions_team_raw)

fig_roc_team_all, ax_roc_team_all = plt.subplots(
    figsize=(base_fig_width, base_fig_height)
)
ax_roc_team_all.plot(fpr, tpr, label="ROC curve (AUC = %0.2f)" % auc_score)
ax_roc_team_all.plot([0, 1], [0, 1], "k--")  # Random guessing line
ax_roc_team_all.set_xlabel("False Positive Rate")
ax_roc_team_all.set_ylabel("True Positive Rate")
ax_roc_team_all.legend(loc="lower right")
plt.show()

# %% [markdown]
# ##### Model coefficients:

# %%
# | label: tbl-team_all
# | tbl-cap: Logistic regression model coefficients obtained by fitting the model using all team attributes without modification.
params_team_all = result_team_raw.params[1:].to_frame(name="Coefficient")
params_team_all["p-value"] = result_team_raw.pvalues[1:].values
params_team_all.index = match_win_df_team.drop(columns=cols_to_drop).columns
params_team_all.sort_values("Coefficient", ascending=False).style.applymap(
    lambda value: disf.rb_cell_highlight(value, threshold=significance, higher=False),
    subset="p-value",
)
# Out:
# <style type="text/css">
# #T_2f333_row0_col1, #T_2f333_row1_col1, #T_2f333_row2_col1, #T_2f333_row3_col1, #T_2f333_row14_col1, #T_2f333_row15_col1, #T_2f333_row16_col1, #T_2f333_row17_col1 {
#   background-color: rgba(0, 0, 255, 0.25);
# }
# #T_2f333_row4_col1, #T_2f333_row5_col1, #T_2f333_row6_col1, #T_2f333_row7_col1, #T_2f333_row8_col1, #T_2f333_row9_col1, #T_2f333_row10_col1, #T_2f333_row11_col1, #T_2f333_row12_col1, #T_2f333_row13_col1 {
#   background-color: rgba(255, 0, 0, 0.25);
# }
# </style>
# <table id="T_2f333">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f333_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_2f333_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f333_level0_row0" class="row_heading level0 row0" >chanceCreationCrossing</th>
#       <td id="T_2f333_row0_col0" class="data row0 col0" >0.152454</td>
#       <td id="T_2f333_row0_col1" class="data row0 col1" >0.000038</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row1" class="row_heading level0 row1" >defencePressure</th>
#       <td id="T_2f333_row1_col0" class="data row1 col0" >0.144317</td>
#       <td id="T_2f333_row1_col1" class="data row1 col1" >0.000418</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row2" class="row_heading level0 row2" >defenceAggression</th>
#       <td id="T_2f333_row2_col0" class="data row2 col0" >0.108790</td>
#       <td id="T_2f333_row2_col1" class="data row2 col1" >0.005650</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row3" class="row_heading level0 row3" >buildUpPlayPassing_away</th>
#       <td id="T_2f333_row3_col0" class="data row3 col0" >0.102199</td>
#       <td id="T_2f333_row3_col1" class="data row3 col1" >0.007511</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row4" class="row_heading level0 row4" >chanceCreationShooting</th>
#       <td id="T_2f333_row4_col0" class="data row4 col0" >0.058529</td>
#       <td id="T_2f333_row4_col1" class="data row4 col1" >0.102195</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row5" class="row_heading level0 row5" >chanceCreationPassing</th>
#       <td id="T_2f333_row5_col0" class="data row5 col0" >0.055155</td>
#       <td id="T_2f333_row5_col1" class="data row5 col1" >0.146516</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row6" class="row_heading level0 row6" >chanceCreationPassing_away</th>
#       <td id="T_2f333_row6_col0" class="data row6 col0" >0.037273</td>
#       <td id="T_2f333_row6_col1" class="data row6 col1" >0.326949</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row7" class="row_heading level0 row7" >buildUpPlaySpeed_away</th>
#       <td id="T_2f333_row7_col0" class="data row7 col0" >0.000322</td>
#       <td id="T_2f333_row7_col1" class="data row7 col1" >0.993224</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row8" class="row_heading level0 row8" >buildUpPlayDribbling</th>
#       <td id="T_2f333_row8_col0" class="data row8 col0" >-0.009318</td>
#       <td id="T_2f333_row8_col1" class="data row8 col1" >0.800382</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row9" class="row_heading level0 row9" >buildUpPlayDribbling_away</th>
#       <td id="T_2f333_row9_col0" class="data row9 col0" >-0.010299</td>
#       <td id="T_2f333_row9_col1" class="data row9 col1" >0.777933</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row10" class="row_heading level0 row10" >defenceTeamWidth_away</th>
#       <td id="T_2f333_row10_col0" class="data row10 col0" >-0.032423</td>
#       <td id="T_2f333_row10_col1" class="data row10 col1" >0.371291</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row11" class="row_heading level0 row11" >chanceCreationShooting_away</th>
#       <td id="T_2f333_row11_col0" class="data row11 col0" >-0.044613</td>
#       <td id="T_2f333_row11_col1" class="data row11 col1" >0.212893</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row12" class="row_heading level0 row12" >defencePressure_away</th>
#       <td id="T_2f333_row12_col0" class="data row12 col0" >-0.067938</td>
#       <td id="T_2f333_row12_col1" class="data row12 col1" >0.095564</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row13" class="row_heading level0 row13" >chanceCreationCrossing_away</th>
#       <td id="T_2f333_row13_col0" class="data row13 col0" >-0.068292</td>
#       <td id="T_2f333_row13_col1" class="data row13 col1" >0.063724</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row14" class="row_heading level0 row14" >defenceTeamWidth</th>
#       <td id="T_2f333_row14_col0" class="data row14 col0" >-0.074180</td>
#       <td id="T_2f333_row14_col1" class="data row14 col1" >0.042071</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row15" class="row_heading level0 row15" >buildUpPlaySpeed</th>
#       <td id="T_2f333_row15_col0" class="data row15 col0" >-0.075989</td>
#       <td id="T_2f333_row15_col1" class="data row15 col1" >0.043995</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row16" class="row_heading level0 row16" >defenceAggression_away</th>
#       <td id="T_2f333_row16_col0" class="data row16 col0" >-0.117195</td>
#       <td id="T_2f333_row16_col1" class="data row16 col1" >0.002749</td>
#     </tr>
#     <tr>
#       <th id="T_2f333_level0_row17" class="row_heading level0 row17" >buildUpPlayPassing</th>
#       <td id="T_2f333_row17_col0" class="data row17 col0" >-0.119939</td>
#       <td id="T_2f333_row17_col1" class="data row17 col1" >0.001766</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Team unmodified attribute summary

# %% [markdown]
# The logistic regression model, utilizing 18 team attributes, achieved a 58% accuracy in predicting game outcomes, slightly surpassing the dataset's natural skew. This observation is further supported by the ROC curve, which yielded an area under the curve (AUC) of 0.60. Since we are specifically interested in predicting home winning matches, the model's precision for home wins was 0.55, while the recall was only 0.33. This outcome is favorable for betting strategies, as we prioritize precise positive predictions and have the option not to place a bet.
#
# The significance analysis of the logistic regression model revealed that the top 4 largest coefficients and the lowest coefficients were deemed statistically significant, while those coefficients falling in between were considered insignificant.
#
# Despite these results, the model's performance-to-feature ratio is not satisfactory. To address this, we will focus on reducing the number of features by utilizing the differences of these attributes between home and away teams.

# %% [markdown]
# #### Logistic regression with home-away team attribute differences

# %% [markdown]
# ##### Training the model and predictions:

# %%
home_win_team_features_dif = match_win_df_team.drop(columns=cols_to_drop)
home_win_team_features_dif = (
    home_win_team_features_dif[team_numeric_cols].values
    - home_win_team_features_dif[[col + "_away" for col in team_numeric_cols]].values
)

team_feat_names = [i + "_diff" for i in team_numeric_cols]
home_win_team_features_dif = pd.DataFrame(
    home_win_team_features_dif,
    columns=team_feat_names,
    index=home_win_target_team.index,
)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    home_win_team_features_dif, home_win_target_team, test_size=0.33, random_state=1
)

# Scale the data
team_feat_ratio_scaler = StandardScaler()
X_train = team_feat_ratio_scaler.fit_transform(X_train)
X_test = team_feat_ratio_scaler.fit_transform(X_test)

# Create and fit the logistic regression model
logit_model_team_dif = sm.Logit(y_train, sm.add_constant(X_train))
result_team_dif = logit_model_team_dif.fit()

# Predict using the trained model
predictions_team_dif = result_team_dif.predict(sm.add_constant(X_test))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.672126
#          Iterations 4

# %% [markdown]
# ##### Classification report:

# %%
print(classification_report(y_test, predictions_team_dif.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.79      0.68      1010
#            1       0.56      0.32      0.41       826
#
#     accuracy                           0.58      1836
#    macro avg       0.57      0.56      0.54      1836
# weighted avg       0.57      0.58      0.55      1836

# %% [markdown]
# ##### Model coefficients:

# %%
# | label: tbl-team_dif
# | tbl-cap: Logistic regression model coefficients obtained by fitting the model using the differences of team attributes.
params_team_all = result_team_dif.params[1:].to_frame(name="Coefficient")
params_team_all["p-value"] = result_team_dif.pvalues[1:].values
params_team_all.index = team_feat_names
params_team_all.sort_values("Coefficient", ascending=False).style.applymap(
    lambda value: disf.rb_cell_highlight(value, threshold=significance, higher=False),
    subset="p-value",
)
# Out:
# <style type="text/css">
# #T_801dc_row0_col1, #T_801dc_row1_col1, #T_801dc_row2_col1, #T_801dc_row8_col1 {
#   background-color: rgba(0, 0, 255, 0.25);
# }
# #T_801dc_row3_col1, #T_801dc_row4_col1, #T_801dc_row5_col1, #T_801dc_row6_col1, #T_801dc_row7_col1 {
#   background-color: rgba(255, 0, 0, 0.25);
# }
# </style>
# <table id="T_801dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_801dc_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_801dc_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_801dc_level0_row0" class="row_heading level0 row0" >chanceCreationCrossing_diff</th>
#       <td id="T_801dc_row0_col0" class="data row0 col0" >0.153614</td>
#       <td id="T_801dc_row0_col1" class="data row0 col1" >0.000030</td>
#     </tr>
#     <tr>
#       <th id="T_801dc_level0_row1" class="row_heading level0 row1" >defenceAggression_diff</th>
#       <td id="T_801dc_row1_col0" class="data row1 col0" >0.152408</td>
#       <td id="T_801dc_row1_col1" class="data row1 col1" >0.000104</td>
#     </tr>
#     <tr>
#       <th id="T_801dc_level0_row2" class="row_heading level0 row2" >defencePressure_diff</th>
#       <td id="T_801dc_row2_col0" class="data row2 col0" >0.149047</td>
#       <td id="T_801dc_row2_col1" class="data row2 col1" >0.000379</td>
#     </tr>
#     <tr>
#       <th id="T_801dc_level0_row3" class="row_heading level0 row3" >chanceCreationShooting_diff</th>
#       <td id="T_801dc_row3_col0" class="data row3 col0" >0.068049</td>
#       <td id="T_801dc_row3_col1" class="data row3 col1" >0.052230</td>
#     </tr>
#     <tr>
#       <th id="T_801dc_level0_row4" class="row_heading level0 row4" >chanceCreationPassing_diff</th>
#       <td id="T_801dc_row4_col0" class="data row4 col0" >0.011143</td>
#       <td id="T_801dc_row4_col1" class="data row4 col1" >0.766147</td>
#     </tr>
#     <tr>
#       <th id="T_801dc_level0_row5" class="row_heading level0 row5" >buildUpPlayDribbling_diff</th>
#       <td id="T_801dc_row5_col0" class="data row5 col0" >0.003255</td>
#       <td id="T_801dc_row5_col1" class="data row5 col1" >0.925469</td>
#     </tr>
#     <tr>
#       <th id="T_801dc_level0_row6" class="row_heading level0 row6" >defenceTeamWidth_diff</th>
#       <td id="T_801dc_row6_col0" class="data row6 col0" >-0.027599</td>
#       <td id="T_801dc_row6_col1" class="data row6 col1" >0.448482</td>
#     </tr>
#     <tr>
#       <th id="T_801dc_level0_row7" class="row_heading level0 row7" >buildUpPlaySpeed_diff</th>
#       <td id="T_801dc_row7_col0" class="data row7 col0" >-0.052334</td>
#       <td id="T_801dc_row7_col1" class="data row7 col1" >0.159906</td>
#     </tr>
#     <tr>
#       <th id="T_801dc_level0_row8" class="row_heading level0 row8" >buildUpPlayPassing_diff</th>
#       <td id="T_801dc_row8_col0" class="data row8 col0" >-0.155055</td>
#       <td id="T_801dc_row8_col1" class="data row8 col1" >0.000062</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Reducing the number of features in half by calculating the difference between home and away teams did not compromise the predictive power of the model. Furthermore only four features were determined to be significant, as expected most of these were positive (diiferences in chance creation crossing, defence aggression, and defence pressiure), yet one negative feature "build up play passing" was also significant.

# %% [markdown]
# ##### Building a model with only significant features:

# %%
# Selecting significant features based on previous model
significant_team_features = params_team_all.loc[
    params_team_all["p-value"] < significance
].index.to_list()

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    home_win_team_features_dif[significant_team_features],
    home_win_target_team,
    test_size=0.33,
    random_state=1,
)

# Scale the data
team_feat_ratio_scaler = StandardScaler()
X_train = team_feat_ratio_scaler.fit_transform(X_train)
X_test = team_feat_ratio_scaler.fit_transform(X_test)

# Create and fit the logistic regression model
logit_model_team_dif = sm.Logit(y_train, sm.add_constant(X_train))
result_team_dif = logit_model_team_dif.fit()

# Predict using the trained model
predictions_team_dif = result_team_dif.predict(sm.add_constant(X_test))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.672929
#          Iterations 4

# %%
print(classification_report(y_test, predictions_team_dif.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.81      0.68      1010
#            1       0.58      0.32      0.41       826
#
#     accuracy                           0.59      1836
#    macro avg       0.58      0.56      0.55      1836
# weighted avg       0.58      0.59      0.56      1836

# %%
# | label: fig-roc_team_dif
# | fig-cap: Receiver operating characteristic curve of the home-win predictions made by a logistic regression model trained on significant team attribute differences.

fpr, tpr, thresholds = roc_curve(y_test, predictions_team_dif)
auc_score = roc_auc_score(y_test, predictions_team_dif)

fig_roc_team_dif, ax_roc_team_dif = plt.subplots(
    figsize=(base_fig_width, base_fig_height)
)
ax_roc_team_dif.plot(fpr, tpr, label="ROC curve (AUC = %0.2f)" % auc_score)
ax_roc_team_dif.plot([0, 1], [0, 1], "k--")  # Random guessing line
ax_roc_team_dif.set_xlabel("False Positive Rate")
ax_roc_team_dif.set_ylabel("True Positive Rate")
ax_roc_team_dif.legend(loc="lower right")
plt.show()

# %% [markdown]
# #### Team attribute summary

# %% [markdown]
# By calculating the differences in team attributes and subsequently selecting only the significant differences, the model's performance was not compromised. On the contrary, it even exhibited an increase of one percentage point in accuracy and precision when predicting home team winning matches. As a result, these four significant team attribute differences will be retained and utilized in the final model.

# %% [markdown]
# ### Player Attributes

# %% [markdown]
# To avoid outcome data leakage and address the dynamic nature of player attributes and team composition, a custom class called "MatchPlayers" was implemented. This class includes a subclass named "Player" and incorporates several methods to handle the data preparation challenges effectively.
#
# Since player attributes may undergo updates over time, it is essential to ensure that the model does not have access to future information when making predictions. To achieve this, the "MatchPlayers" class ensures that player attribute data is appropriately partitioned and processed, preventing any leakage of information from future matches.
#
# Additionally, teams consist of 11 different players, and their compositions can change over time. Managing these variations is vital for accurate predictions. The class efficiently handles team composition changes, allowing for proper data alignment and processing during model training and evaluation.
#
# Furthermore, the inclusion of goalkeepers presents an additional complexity, as they possess a distinct set of attributes compared to other players as was shown in @tbl-rating_att_corr. The "MatchPlayers" class addresses this issue by appropriately differentiating and handling goalkeeper attributes to ensure their relevance in the model without compromising overall data integrity.
#
# Moreover, the "MatchPlayers" class also includes functions to export different sets of features, as well as their transformed variants, allowing for flexible feature selection and manipulation during the model building process. This feature further enhances the adaptability and utility of the custom class in preparing the data for predictive modeling.

# %% [markdown]
# ##### Getting the date relevant attributes of each match player using the MatchPlayers class Player subclass and their functions:
# 10+ min processing time warning!

# %%
# only using rows with team attributes
match_win_df_player = match_win_df.copy()[
    match_win_df.index.isin(match_win_df_team.index)
]

# Creating MatchPlayers objects for each match
match_players_series = {}
for i in match_win_df_player.index:
    match_players_series[i] = MatchPlayers()
match_players_series = pd.Series(match_players_series, name="match_players")
match_win_df_player = match_win_df_player.join(match_players_series)

# Using the MatchPlayers methods and the player subclass and it's methods to store date
# player attribute data for each match
for index, row in match_raw[match_raw.index.isin(match_win_df_player.index)].iterrows():
    match_win_df_player.at[index, "match_players"].get_data(row)
    match_win_df_player.at[index, "match_players"].get_player_positions()
    match_win_df_player.at[index, "match_players"].get_player_ids()
    match_win_df_player.at[index, "match_players"].home_players[
        "goaly"
    ].get_player_attributes(player_attr_raw, row["date"])
    match_win_df_player.at[index, "match_players"].away_players[
        "goaly"
    ].get_player_attributes(player_attr_raw, row["date"])
    for player in match_win_df_player.at[index, "match_players"].home_players[
        "players"
    ]:
        player.get_player_attributes(player_attr_raw, row["date"])
    for player in match_win_df_player.at[index, "match_players"].away_players[
        "players"
    ]:
        player.get_player_attributes(player_attr_raw, row["date"])

# %% [markdown]
# ##### Optional code for saving and loading sorted match data for further use:

# %%
# import pickle

# # with open('match_win_df_player.pkl', 'wb') as file:
# #     pickle.dump(match_win_df_player, file)

# with open("match_win_df_player.pkl", "rb") as file:
#     match_win_df_player = pickle.load(file)

# %% [markdown]
# By employing the custom class "MatchPlayers" with its "Player" subclass and various methods, the data preparation challenges related to player attributes, team compositions, and goalkeeper attributes were effectively overcome, providing a robust foundation for building an accurate predictive model.

# %% [markdown]
# #### Logistic regression using all attributes

# %% [markdown]
# Due to the large number of different players and their attributes in a single match, the resulting feature set from the "MatchPlayers" class can consist of up to 770 different features. However, with only around five thousand samples available, this leads to an unbalanced feature-to-sample ratio in our training set, necessitating feature reduction.
#
# In the first iteration of the model, all possible player attributes without any modifications were utilized. These attributes were then used to train a logistic regression model to predict whether the home team wins the match. To mitigate potential overfitting and reduce the inclusion of less important features, the fitting function employed regularization with an alpha value of 0.1.

# %% [markdown]
# ##### Exporting all player attributes:

# %%
# Export all player attributes for each mach in to a dictionary
player_att_dict = {}
for i in match_win_df_player.index:
    player_att_dict[i] = match_win_df_player.at[
        i, "match_players"
    ].export_player_attributes(player_attr_numeric, how="all")

# Merging with the match dataframe
match_win_players = pd.DataFrame.from_dict(player_att_dict, orient="index").join(
    match_win_df["home_team_win"]
)

# Dropping rows with missing values
match_win_players.dropna(inplace=True)

# In some cases missing attributes were returned as empty dictionaries, dropping these rows
match_win_players = match_win_players[
    match_win_players.apply(
        lambda x: False if dict in [type(i) for i in x.values] else True, axis=1
    )
]

# %% [markdown]
# ##### Logistic Regression with all player attributes:

# %%
home_win_target_player = match_win_players["home_team_win"]
home_win_features_player = match_win_players.drop(columns="home_team_win")

# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    home_win_features_player, home_win_target_player, test_size=0.33, random_state=1
)

# Scaling the data
player_feat_scaler = StandardScaler()
X_train = player_feat_scaler.fit_transform(X_train)
X_test = player_feat_scaler.fit_transform(X_test)

# Create and fit the logistic regression model
logit_model_player_all = sm.Logit(y_train, sm.add_constant(X_train))
result_player_all = logit_model_player_all.fit_regularized(
    method="l1_cvxopt_cp", alpha=0.1, disp=0
)

# Predict using the trained model
predictions_player_all = result_player_all.predict(sm.add_constant(X_test))

# %% [markdown]
# ##### Classification report:

# %%
print(classification_report(y_test, predictions_player_all.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62       933
#            1       0.52      0.52      0.52       736
#
#     accuracy                           0.58      1669
#    macro avg       0.57      0.57      0.57      1669
# weighted avg       0.58      0.58      0.58      1669

# %% [markdown]
# ##### Area under the receiver operating characteristic curve:

# %%
roc_auc_score(y_test, predictions_player_all).round(2)
# Out:
# 0.62

# %% [markdown]
# ##### What is the test data set skew?

# %%
y_test.value_counts(normalize=True).to_frame("Fraction")
# Out:
#    Fraction
# 0  0.559017
# 1  0.440983

# %% [markdown]
# ##### Coefficients and their p-values:

# %%
# | label: tbl-player_all_pos
# | tbl-cap: Largest positive logistic regression model coefficients obtained by fitting the model using all player attributes without modification.

params_player_all = result_player_all.params[1:].to_frame(name="Coefficient")
params_player_all["p-value"] = result_player_all.pvalues[1:].values
params_player_all.index = home_win_features_player.columns
display(
    params_player_all.sort_values("Coefficient", ascending=False)
    .head()
    .style.applymap(
        lambda value: disf.rb_cell_highlight(
            value, threshold=significance, higher=False
        ),
        subset="p-value",
    )
    .format("{:.3f}")
)
# Out:
# <style type="text/css">
# #T_5a68d_row0_col1, #T_5a68d_row1_col1, #T_5a68d_row3_col1 {
#   background-color: rgba(0, 0, 255, 0.25);
# }
# #T_5a68d_row2_col1, #T_5a68d_row4_col1 {
#   background-color: rgba(255, 0, 0, 0.25);
# }
# </style>
# <table id="T_5a68d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a68d_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_5a68d_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a68d_level0_row0" class="row_heading level0 row0" >overall_rating_A_6</th>
#       <td id="T_5a68d_row0_col0" class="data row0 col0" >0.503</td>
#       <td id="T_5a68d_row0_col1" class="data row0 col1" >0.007</td>
#     </tr>
#     <tr>
#       <th id="T_5a68d_level0_row1" class="row_heading level0 row1" >marking_A_2</th>
#       <td id="T_5a68d_row1_col0" class="data row1 col0" >0.458</td>
#       <td id="T_5a68d_row1_col1" class="data row1 col1" >0.004</td>
#     </tr>
#     <tr>
#       <th id="T_5a68d_level0_row2" class="row_heading level0 row2" >overall_rating_H_2</th>
#       <td id="T_5a68d_row2_col0" class="data row2 col0" >0.425</td>
#       <td id="T_5a68d_row2_col1" class="data row2 col1" >0.172</td>
#     </tr>
#     <tr>
#       <th id="T_5a68d_level0_row3" class="row_heading level0 row3" >ball_control_A_10</th>
#       <td id="T_5a68d_row3_col0" class="data row3 col0" >0.388</td>
#       <td id="T_5a68d_row3_col1" class="data row3 col1" >0.010</td>
#     </tr>
#     <tr>
#       <th id="T_5a68d_level0_row4" class="row_heading level0 row4" >sliding_tackle_H_gk</th>
#       <td id="T_5a68d_row4_col0" class="data row4 col0" >0.324</td>
#       <td id="T_5a68d_row4_col1" class="data row4 col1" >0.063</td>
#     </tr>
#   </tbody>
# </table>

# %%
# | label: tbl-player_all_neg
# | tbl-cap: Largest negative logistic regression model coefficients obtained by fitting the model using all player attributes without modification.

display(
    params_player_all.sort_values("Coefficient", ascending=False)
    .tail()
    .style.applymap(
        lambda value: disf.rb_cell_highlight(
            value, threshold=significance, higher=False
        ),
        subset="p-value",
    )
    .format("{:.3f}")
)
# Out:
# <style type="text/css">
# #T_bddcf_row0_col1, #T_bddcf_row3_col1, #T_bddcf_row4_col1 {
#   background-color: rgba(255, 0, 0, 0.25);
# }
# #T_bddcf_row1_col1, #T_bddcf_row2_col1 {
#   background-color: rgba(0, 0, 255, 0.25);
# }
# </style>
# <table id="T_bddcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bddcf_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_bddcf_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bddcf_level0_row0" class="row_heading level0 row0" >overall_rating_H_gk</th>
#       <td id="T_bddcf_row0_col0" class="data row0 col0" >-0.500</td>
#       <td id="T_bddcf_row0_col1" class="data row0 col1" >0.562</td>
#     </tr>
#     <tr>
#       <th id="T_bddcf_level0_row1" class="row_heading level0 row1" >sliding_tackle_H_5</th>
#       <td id="T_bddcf_row1_col0" class="data row1 col0" >-0.507</td>
#       <td id="T_bddcf_row1_col1" class="data row1 col1" >0.006</td>
#     </tr>
#     <tr>
#       <th id="T_bddcf_level0_row2" class="row_heading level0 row2" >overall_rating_H_10</th>
#       <td id="T_bddcf_row2_col0" class="data row2 col0" >-0.523</td>
#       <td id="T_bddcf_row2_col1" class="data row2 col1" >0.047</td>
#     </tr>
#     <tr>
#       <th id="T_bddcf_level0_row3" class="row_heading level0 row3" >overall_rating_A_2</th>
#       <td id="T_bddcf_row3_col0" class="data row3 col0" >-0.606</td>
#       <td id="T_bddcf_row3_col1" class="data row3 col1" >0.211</td>
#     </tr>
#     <tr>
#       <th id="T_bddcf_level0_row4" class="row_heading level0 row4" >overall_rating_A_gk</th>
#       <td id="T_bddcf_row4_col0" class="data row4 col0" >-1.033</td>
#       <td id="T_bddcf_row4_col1" class="data row4 col1" >0.236</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The model utilizing all player attributes achieved a similar accuracy of 58% compared to the one trained on team attributes, but it involved the use of a substantially higher number of features (770 attributes). Furthermore, this model exhibited a higher recall, which compromises potential profits from betting due to increased false positives.
#
# Given the large number of features relative to the limited number of samples, even when employing lasso regression to penalize large coefficients, some coefficients with significant magnitudes had p-values above the significance level. As a result, it becomes evident that to enhance the model's predictive power and simplicity, it is necessary to reduce the number of features.

# %% [markdown]
# #### Logistic regression using the differences of player attributes:

# %% [markdown]
# The most straightforward approach to feature reduction is employed here by utilizing the differences in attributes between home and away players instead of considering attributes from all players individually. By adopting this method, the number of features is effectively reduced by half.
#
# To address the challenge of distinguishing the importance of players in specific positions, a more generalized approach is implemented. Instead of using separate attribute differences for each player, the average of all non-goalkeeper players' attributes is utilized. This further reduces the number of features significantly, resulting in a final set of 70 features from the initial 770.
#
# Many of the attributes in this data set is at least moderately correlated with each other, therefore at this step only very highly correlated (Pearson's r>0.85) features will be removed.
#
# This reduction in the number of features streamlines the model, making it more interpretable and computationally efficient while retaining relevant information for predicting home team wins in football matches.

# %% [markdown]
# ##### Fetching relevant differences of player attributes:

# %%
player_att_dict = {}
for i in match_win_df_player.index:
    player_att_dict[i] = match_win_df_player.at[
        i, "match_players"
    ].export_player_attributes(player_attr_numeric, how="avg_diff")

match_win_players = pd.DataFrame.from_dict(player_att_dict, orient="index").join(
    match_win_df["home_team_win"]
)

# Dropping rows with missing values
match_win_players.dropna(inplace=True)

# In some cases missing attributes were returned as empty dictionaries, dropping these rows
match_win_players = match_win_players[
    match_win_players.apply(
        lambda x: False if dict in [type(i) for i in x.values] else True, axis=1
    )
]

# %% [markdown]
# ##### Checking for highly correlated features:

# %%
home_win_target_playerdif = match_win_players["home_team_win"]
home_win_features_playerdif = match_win_players.drop(columns="home_team_win")
disf.get_correlation_pairs(home_win_features_playerdif, 0.85, -0.85)
# Out:
#      r-value                                       feature_pair
# 0   0.934279      (overall_rating_avg_diff, potential_avg_diff)
# 1   0.898457  (overall_rating_avg_diff, short_passing_avg_diff)
# 2   0.922278   (overall_rating_avg_diff, ball_control_avg_diff)
# 3   0.928650      (overall_rating_avg_diff, reactions_avg_diff)
# 4   0.874719  (overall_rating_avg_diff_gk, gk_diving_avg_dif...
# 5   0.879793  (overall_rating_avg_diff_gk, gk_positioning_av...
# 6   0.866173  (overall_rating_avg_diff_gk, gk_reflexes_avg_d...
# 8   0.851725       (potential_avg_diff, short_passing_avg_diff)
# 9   0.878652        (potential_avg_diff, ball_control_avg_diff)
# 10  0.853437           (potential_avg_diff, reactions_avg_diff)
# 13  0.891782    (short_passing_avg_diff, long_passing_avg_diff)
# 14  0.916172    (ball_control_avg_diff, short_passing_avg_diff)
# 15  0.868316          (vision_avg_diff, short_passing_avg_diff)
# 16  0.902176        (ball_control_avg_diff, dribbling_avg_diff)
# 22  0.853120        (ball_control_avg_diff, reactions_avg_diff)
# 23  0.864553           (ball_control_avg_diff, vision_avg_diff)
# 24  0.892358     (acceleration_avg_diff, sprint_speed_avg_diff)
# 31  0.899832  (sliding_tackle_avg_diff, standing_tackle_avg_...

# %% [markdown]
# ##### Dropping clusters of correlated features:

# %%
# Potential
corr_player_features = ["potential_avg_diff"]

# Sliding/standing tackle pair
corr_player_features.extend(["sliding_tackle_avg_diff"])

# Cluster correlated with ball control
corr_player_features.extend(["ball_control_avg_diff"])

# short/long passing
corr_player_features.extend(["short_passing_avg_diff"])

# Sprint/acceleration
corr_player_features.extend(["acceleration_avg_diff"])

# Goal-keeper attributes
corr_player_features.extend(
    [
        "gk_positioning_avg_diff_gk",
        "overall_rating_avg_diff_gk",
        "gk_reflexes_avg_diff_gk",
    ]
)

# Reactions
corr_player_features.extend(["reactions_avg_diff"])

home_win_features_playerdif = home_win_features_playerdif.drop(
    columns=corr_player_features
)

# %% [markdown]
# ##### Checking if all highly correlated features were removed:

# %%
disf.get_correlation_pairs(home_win_features_playerdif, 0.85, -0.85)
# Out:
# Empty DataFrame
# Columns: [r-value, feature_pair]
# Index: []

# %% [markdown]
# ##### Logistic regression model training and predictions:

# %%
# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    home_win_features_playerdif,
    home_win_target_playerdif,
    test_size=0.33,
    random_state=1,
)

# Scaling the data
player_feat_scaler = StandardScaler()
X_train = player_feat_scaler.fit_transform(X_train)
X_test = player_feat_scaler.fit_transform(X_test)

# Create and fit the logistic regression model
logit_model_player_dif = sm.Logit(y_train, sm.add_constant(X_train))
result_player_dif = logit_model_player_dif.fit_regularized(
    method="l1_cvxopt_cp", alpha=0.1, disp=0
)

# Predict using the trained model
predictions_player_dif = result_player_dif.predict(sm.add_constant(X_test))

# %% [markdown]
# ##### Classification report:

# %%
print(classification_report(y_test, predictions_player_dif.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.74      0.70       933
#            1       0.62      0.53      0.57       736
#
#     accuracy                           0.65      1669
#    macro avg       0.64      0.64      0.64      1669
# weighted avg       0.64      0.65      0.64      1669

# %% [markdown]
# ##### Area under the receiver operating characteristic curve:

# %%
roc_auc_score(y_test, predictions_player_dif).round(2)
# Out:
# 0.7

# %% [markdown]
# ##### The most important coefficients and their p-values

# %%
# | label: tbl-player_dif_pos
# | tbl-cap: Largest positive logistic regression model coefficients obtained by fitting the model using differences in averages of player attributes.
params_player_dif = result_player_dif.params[1:].to_frame(name="Coefficient")
params_player_dif["p-value"] = result_player_dif.pvalues[1:].values
params_player_dif.index = home_win_features_playerdif.columns
display(
    params_player_dif.sort_values("Coefficient", ascending=False)
    .head()
    .style.applymap(
        lambda value: disf.rb_cell_highlight(
            value, threshold=significance, higher=False
        ),
        subset="p-value",
    )
    .format("{:.3f}")
)
# Out:
# <style type="text/css">
# #T_47b7f_row0_col1, #T_47b7f_row1_col1, #T_47b7f_row2_col1 {
#   background-color: rgba(0, 0, 255, 0.25);
# }
# #T_47b7f_row3_col1, #T_47b7f_row4_col1 {
#   background-color: rgba(255, 0, 0, 0.25);
# }
# </style>
# <table id="T_47b7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47b7f_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_47b7f_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47b7f_level0_row0" class="row_heading level0 row0" >overall_rating_avg_diff</th>
#       <td id="T_47b7f_row0_col0" class="data row0 col0" >0.511</td>
#       <td id="T_47b7f_row0_col1" class="data row0 col1" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_47b7f_level0_row1" class="row_heading level0 row1" >vision_avg_diff</th>
#       <td id="T_47b7f_row1_col0" class="data row1 col0" >0.223</td>
#       <td id="T_47b7f_row1_col1" class="data row1 col1" >0.021</td>
#     </tr>
#     <tr>
#       <th id="T_47b7f_level0_row2" class="row_heading level0 row2" >finishing_avg_diff</th>
#       <td id="T_47b7f_row2_col0" class="data row2 col0" >0.195</td>
#       <td id="T_47b7f_row2_col1" class="data row2 col1" >0.018</td>
#     </tr>
#     <tr>
#       <th id="T_47b7f_level0_row3" class="row_heading level0 row3" >acceleration_avg_diff_gk</th>
#       <td id="T_47b7f_row3_col0" class="data row3 col0" >0.108</td>
#       <td id="T_47b7f_row3_col1" class="data row3 col1" >0.070</td>
#     </tr>
#     <tr>
#       <th id="T_47b7f_level0_row4" class="row_heading level0 row4" >standing_tackle_avg_diff</th>
#       <td id="T_47b7f_row4_col0" class="data row4 col0" >0.104</td>
#       <td id="T_47b7f_row4_col1" class="data row4 col1" >0.241</td>
#     </tr>
#   </tbody>
# </table>

# %%
# | label: tbl-player_dif_neg
# | tbl-cap: Largest negative logistic regression model coefficients obtained by fitting the model using differences in averages of player attributes.
display(
    params_player_dif.sort_values("Coefficient", ascending=False)
    .tail()
    .style.applymap(
        lambda value: disf.rb_cell_highlight(
            value, threshold=significance, higher=False
        ),
        subset="p-value",
    )
    .format("{:.3f}")
)
# Out:
# <style type="text/css">
# #T_51bfc_row0_col1, #T_51bfc_row1_col1, #T_51bfc_row2_col1, #T_51bfc_row3_col1, #T_51bfc_row4_col1 {
#   background-color: rgba(255, 0, 0, 0.25);
# }
# </style>
# <table id="T_51bfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51bfc_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_51bfc_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51bfc_level0_row0" class="row_heading level0 row0" >reactions_avg_diff_gk</th>
#       <td id="T_51bfc_row0_col0" class="data row0 col0" >-0.077</td>
#       <td id="T_51bfc_row0_col1" class="data row0 col1" >0.197</td>
#     </tr>
#     <tr>
#       <th id="T_51bfc_level0_row1" class="row_heading level0 row1" >stamina_avg_diff_gk</th>
#       <td id="T_51bfc_row1_col0" class="data row1 col0" >-0.078</td>
#       <td id="T_51bfc_row1_col1" class="data row1 col1" >0.055</td>
#     </tr>
#     <tr>
#       <th id="T_51bfc_level0_row2" class="row_heading level0 row2" >shot_power_avg_diff</th>
#       <td id="T_51bfc_row2_col0" class="data row2 col0" >-0.090</td>
#       <td id="T_51bfc_row2_col1" class="data row2 col1" >0.271</td>
#     </tr>
#     <tr>
#       <th id="T_51bfc_level0_row3" class="row_heading level0 row3" >interceptions_avg_diff</th>
#       <td id="T_51bfc_row3_col0" class="data row3 col0" >-0.100</td>
#       <td id="T_51bfc_row3_col1" class="data row3 col1" >0.178</td>
#     </tr>
#     <tr>
#       <th id="T_51bfc_level0_row4" class="row_heading level0 row4" >dribbling_avg_diff</th>
#       <td id="T_51bfc_row4_col0" class="data row4 col0" >-0.128</td>
#       <td id="T_51bfc_row4_col1" class="data row4 col1" >0.202</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The reduction in the number of features, achieved by calculating the average differences of player attributes, has significantly improved the predictive power of the model. The model now exhibits an overall accuracy of 65%, an area under the receiver operating characteristic curve (AUC-ROC) of 0.64, and precision and recall values of 0.62 and 0.53, respectively, when predicting home team wins.
#
# Despite this success, it is important to note that not all of the largest coefficients in the model are statistically significant. This indicates a level of uncertainty in their determination and suggests that there is room for further improvement in the model.

# %% [markdown]
# #### Recursive feature elimination

# %% [markdown]
# To further improve the model and address the challenge of reducing the number of features, we will employ Recursive Feature Elimination (RFE) with cross-validation.
#
# RFE with cross-validation allows us to identify the most relevant features that contribute significantly to the model's predictive performance. By iteratively removing less informative features, we can achieve a more efficient and interpretable model and reduce over fitting.

# %%
# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    home_win_features_playerdif,
    home_win_target_playerdif,
    test_size=0.33,
    random_state=1,
)

# Scaling the data
player_feat_scaler = StandardScaler()
X_train = player_feat_scaler.fit_transform(X_train)
X_test = player_feat_scaler.fit_transform(X_test)

# Create RFE object and perform feature selection
logreg_model_player_pre_rfe = LogisticRegression()
rfe_player = RFECV(estimator=logreg_model_player_pre_rfe, cv=10)
rfe_player.fit(X_train, y_train)
rfe_selected_columns = home_win_features_playerdif.columns[rfe_player.support_]

# Select the top features based on RFE
X_train_rfe = rfe_player.transform(X_train)
X_test_rfe = rfe_player.transform(X_test)

# Refit the logistic regression model with selected features
logreg_model_rfe = sm.Logit(y_train, sm.add_constant(X_train_rfe))
result_player_rfe = logreg_model_rfe.fit(disp=0)

# Predict using the trained model with selected features
predictions_rfe = result_player_rfe.predict(sm.add_constant(X_test_rfe))

# %% [markdown]
# ##### Classification report:

# %%
print(classification_report(y_test, predictions_rfe.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.77      0.71       933
#            1       0.64      0.51      0.57       736
#
#     accuracy                           0.66      1669
#    macro avg       0.65      0.64      0.64      1669
# weighted avg       0.65      0.66      0.65      1669

# %% [markdown]
# ##### Receiver operating characteristic curve:

# %%
# | label: fig-roc_player_dif
# | fig-cap: Receiver operating characteristic curve of the home-win predictions made by a logistic regression model trained on player attribute differences selected by RFE.

fpr, tpr, thresholds = roc_curve(y_test, predictions_rfe)
auc_score = roc_auc_score(y_test, predictions_rfe)

fig_roc_player_rfe, ax_roc_player_rfe = plt.subplots(
    figsize=(base_fig_width, base_fig_height)
)
ax_roc_player_rfe.plot(fpr, tpr, label="ROC curve (AUC = %0.2f)" % auc_score)
ax_roc_player_rfe.plot([0, 1], [0, 1], "k--")  # Random guessing line
ax_roc_player_rfe.set_xlabel("False Positive Rate")
ax_roc_player_rfe.set_ylabel("True Positive Rate")
ax_roc_player_rfe.legend(loc="lower right")
plt.show()

# %% [markdown]
# ##### Features selected by RFE and their coefficients:

# %%
# | label: tbl-player_rfe
# | tbl-cap: Logistic regression model coefficients obtained by RFE algorithm on a model trained on player attributes.
player_rfe_params = result_player_rfe.params[1:].to_frame(name="Coefficient")
player_rfe_params["p-value"] = result_player_rfe.pvalues[1:].values
player_rfe_params.index = rfe_selected_columns

player_rfe_params.sort_values("Coefficient", ascending=False).head().style.applymap(
    lambda value: disf.rb_cell_highlight(value, threshold=significance, higher=False),
    subset="p-value",
).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_5cc56_row0_col1, #T_5cc56_row1_col1 {
#   background-color: rgba(0, 0, 255, 0.25);
# }
# #T_5cc56_row2_col1 {
#   background-color: rgba(255, 0, 0, 0.25);
# }
# </style>
# <table id="T_5cc56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cc56_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_5cc56_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cc56_level0_row0" class="row_heading level0 row0" >overall_rating_avg_diff</th>
#       <td id="T_5cc56_row0_col0" class="data row0 col0" >0.550</td>
#       <td id="T_5cc56_row0_col1" class="data row0 col1" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_5cc56_level0_row1" class="row_heading level0 row1" >vision_avg_diff</th>
#       <td id="T_5cc56_row1_col0" class="data row1 col0" >0.147</td>
#       <td id="T_5cc56_row1_col1" class="data row1 col1" >0.047</td>
#     </tr>
#     <tr>
#       <th id="T_5cc56_level0_row2" class="row_heading level0 row2" >finishing_avg_diff</th>
#       <td id="T_5cc56_row2_col0" class="data row2 col0" >0.116</td>
#       <td id="T_5cc56_row2_col1" class="data row2 col1" >0.059</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The application of recursive feature elimination has successfully reduced the number of features used in the model to just three: Differences in overall player rating, vision, and finishing. Surprisingly, this reduction in features did not compromise the model's performance, and it continues to exhibit accurate predictions.
#
# The most critical feature among the three was the average difference in overall player rating, indicating its strong influence on the model's predictions. The significance level of the vision feature was just below the threshold, suggesting its importance as well, while the finishing average difference fell beyond the significance level.
#
# This implies that the model can be further simplified into a simple logistic regression, focusing primarily on the average difference in overall player rating.

# %% [markdown]
# #### Simple Logistic Regression

# %%
# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    home_win_features_playerdif["overall_rating_avg_diff"],
    home_win_target_playerdif,
    test_size=0.33,
    random_state=1,
)

# Scaling the data
player_feat_scaler = StandardScaler()
X_train = player_feat_scaler.fit_transform(X_train.values.reshape(-1, 1))
X_test = player_feat_scaler.fit_transform(X_test.values.reshape(-1, 1))

# Fit
logreg_model_overall_rat = sm.Logit(y_train, sm.add_constant(X_train))
result_player_overall_rat = logreg_model_overall_rat.fit(disp=0)

# Predict using the trained model with selected features
predictions_overall_rat = result_player_overall_rat.predict(sm.add_constant(X_test))

# Print the predicted probabilities
print(classification_report(y_test, predictions_overall_rat.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.76      0.71       933
#            1       0.63      0.51      0.56       736
#
#     accuracy                           0.65      1669
#    macro avg       0.65      0.64      0.64      1669
# weighted avg       0.65      0.65      0.65      1669

# %% [markdown]
# ##### Model plot:

# %%
# | label: fig-player_log
# | fig-cap: Performance of the simple logistic regression model based on differences in team player average overall rating.

fig_player_log, ax_player_log = plt.subplots(figsize=(base_fig_width, base_fig_height))
x_values = np.linspace(min(X_test), max(X_test), 100)
# Calculate corresponding y-values using logistic function
y_values = 1 / (
    1
    + np.exp(
        -(
            result_player_overall_rat.params[1] * x_values
            + result_player_overall_rat.params[0]
        )
    )
)

ax_player_log.scatter(X_test, y_test)
ax_player_log.plot(x_values, y_values)
disf.axis_titles(
    ax_player_log, "Difference in average player overall rating", "Home win probability"
)
ax_player_log.set_yticks((0, 1))
ax_player_log.set_yticklabels(("Home loss/tie", "Home win"))
plt.show()

# %% [markdown]
# ##### Area under the receiving operator characteristic curve:

# %%
roc_auc_score(y_test, predictions_overall_rat).round(2)
# Out:
# 0.7

# %% [markdown]
# #### Player attribute feature selection summary

# %% [markdown]
# This section has demonstrated that despite starting with 770 initial player attribute features, we can achieve satisfactory home win outcome predictions using just a single feature: the overall player rating difference. However, upon reducing the model to a single feature from the three selected by RFE, a minor decrease of one point in both positive outcome precision and accuracy was observed.
#
# In light of this finding, all three features (overall player rating difference, vision, and finishing) will be included in the final model.

# %% [markdown]
# ## Game outcome prediction models

# %% [markdown]
# ### Home win

# %% [markdown]
# #### Model Training and predictions

# %% [markdown]
# ##### Creating a dataframe with all features to be used:

# %%
match_win_final_df = match_win_df.merge(
    home_win_features_playerdif[rfe_selected_columns], left_index=True, right_index=True
)

match_win_final_df = match_win_final_df.merge(
    home_win_team_features_dif, left_index=True, right_index=True
)

# %% [markdown]
# ##### Fitting the model and making predictions:

# %%
home_win_final_target = match_win_final_df["home_team_win"]
home_win_final_features = match_win_final_df[
    significant_team_features + rfe_selected_columns.to_list()
]

# Splitting the data into training and test sets
X_train_win, X_test_win, y_train_win, y_test_win = train_test_split(
    home_win_final_features,
    home_win_final_target,
    test_size=0.33,
    random_state=1,
)

home_win_y_test_index = y_test_win.index

# Scaling the data
final_feat_scaler = StandardScaler()
X_train_win = player_feat_scaler.fit_transform(X_train_win)
X_test_win = player_feat_scaler.fit_transform(X_test_win)

# Create and fit the logistic regression model
logit_model_win = sm.Logit(y_train_win, sm.add_constant(X_train_win))
result_win_final = logit_model_win.fit_regularized(
    method="l1_cvxopt_cp", alpha=0.1, disp=0
)

# Predict using the trained model
predictions_win_final = result_win_final.predict(sm.add_constant(X_test_win))

# %% [markdown]
# ##### Classification report:

# %%
print(classification_report(y_test_win, predictions_win_final.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.77      0.72       933
#            1       0.64      0.51      0.57       736
#
#     accuracy                           0.66      1669
#    macro avg       0.65      0.64      0.64      1669
# weighted avg       0.65      0.66      0.65      1669

# %% [markdown]
# ##### Coefficients:

# %%
# | label: tbl-final_coef_home_win
# | tbl-cap: Final home win prediction model logistic regression model coefficients.
params_win_final = result_win_final.params[1:].to_frame(name="Coefficient")
params_win_final["p-value"] = result_win_final.pvalues[1:].values
params_win_final.index = home_win_final_features.columns

params_win_final.sort_values("Coefficient", ascending=False).style.applymap(
    lambda value: disf.rb_cell_highlight(value, threshold=significance, higher=False),
    subset="p-value",
).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_4af10_row0_col1 {
#   background-color: rgba(0, 0, 255, 0.25);
# }
# #T_4af10_row1_col1, #T_4af10_row2_col1, #T_4af10_row3_col1, #T_4af10_row4_col1, #T_4af10_row5_col1, #T_4af10_row6_col1 {
#   background-color: rgba(255, 0, 0, 0.25);
# }
# </style>
# <table id="T_4af10">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4af10_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_4af10_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4af10_level0_row0" class="row_heading level0 row0" >overall_rating_avg_diff</th>
#       <td id="T_4af10_row0_col0" class="data row0 col0" >0.528</td>
#       <td id="T_4af10_row0_col1" class="data row0 col1" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_4af10_level0_row1" class="row_heading level0 row1" >vision_avg_diff</th>
#       <td id="T_4af10_row1_col0" class="data row1 col0" >0.138</td>
#       <td id="T_4af10_row1_col1" class="data row1 col1" >0.067</td>
#     </tr>
#     <tr>
#       <th id="T_4af10_level0_row2" class="row_heading level0 row2" >finishing_avg_diff</th>
#       <td id="T_4af10_row2_col0" class="data row2 col0" >0.117</td>
#       <td id="T_4af10_row2_col1" class="data row2 col1" >0.058</td>
#     </tr>
#     <tr>
#       <th id="T_4af10_level0_row3" class="row_heading level0 row3" >chanceCreationCrossing_diff</th>
#       <td id="T_4af10_row3_col0" class="data row3 col0" >0.045</td>
#       <td id="T_4af10_row3_col1" class="data row3 col1" >0.254</td>
#     </tr>
#     <tr>
#       <th id="T_4af10_level0_row4" class="row_heading level0 row4" >defenceAggression_diff</th>
#       <td id="T_4af10_row4_col0" class="data row4 col0" >0.033</td>
#       <td id="T_4af10_row4_col1" class="data row4 col1" >0.421</td>
#     </tr>
#     <tr>
#       <th id="T_4af10_level0_row5" class="row_heading level0 row5" >defencePressure_diff</th>
#       <td id="T_4af10_row5_col0" class="data row5 col0" >0.018</td>
#       <td id="T_4af10_row5_col1" class="data row5 col1" >0.669</td>
#     </tr>
#     <tr>
#       <th id="T_4af10_level0_row6" class="row_heading level0 row6" >buildUpPlayPassing_diff</th>
#       <td id="T_4af10_row6_col0" class="data row6 col0" >-0.043</td>
#       <td id="T_4af10_row6_col1" class="data row6 col1" >0.299</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Receiver Operating Characteristic Curve:

# %%
# | label: fig-roc_final_home
# | fig-cap: Receiver operating characteristic curve of the home-win predictions made by a logistic regression model trained on player attribute differences selected by RFE.
fpr, tpr, thresholds = roc_curve(y_test_win, predictions_win_final)
auc_score = roc_auc_score(y_test_win, predictions_win_final)

fig_roc, ax_roc = plt.subplots(figsize=(base_fig_width, base_fig_height))
ax_roc.plot(fpr, tpr, label="ROC curve (AUC = %0.2f)" % auc_score)
ax_roc.plot([0, 1], [0, 1], "k--")  # Random guessing line
ax_roc.set_xlabel("False Positive Rate")
ax_roc.set_ylabel("True Positive Rate")
ax_roc.legend(loc="lower right")
plt.show()

# %% [markdown]
# #### Final home-win model summary:

# %% [markdown]
# The incorporation of selected team attributes did not lead to an improvement in the model's performance when compared to using only player attribute features. In fact, it was evident that only the difference in overall player rating was a significant feature in predicting home team win outcomes.

# %% [markdown]
# Indeed, sorting matches into only two possible outcomes (home team win non-win) oversimplifies the prediction process, as matches can also end in a tie. Additionally, considering the possibility of an away team win is essential for a more comprehensive predictive model.
#
# This section will delve further into the use of the selected features (overall player rating difference, vision, and finishing) to predict different match outcomes, including ties and away team wins.

# %% [markdown]
# ### Away win

# %% [markdown]
# ##### Preparing the home loss outcome data:

# %%
match_win_final_df = match_win_final_df.join(match_raw["outcome"])

match_win_final_df["w_l_t"] = match_win_final_df["outcome"].apply(
    lambda x: "Home Win" if x > 0 else ("Home Loss" if x < 0 else "Tie")
)

match_win_final_df["w_l_t"] = pd.Categorical(
    match_win_final_df["w_l_t"],
    categories=["Home Loss", "Tie", "Home Win"],
    ordered=True,
)

match_win_final_df["home_loss"] = match_win_final_df["w_l_t"].apply(
    lambda x: 1 if x == "Home Loss" else 0
)

# %% [markdown]
# ##### Model fitting and predictions:

# %%
home_loss_final_target = match_win_final_df["home_loss"]
home_loss_final_features = match_win_final_df[
    team_feat_names + rfe_selected_columns.to_list()
]

# Splitting the data into training and test sets
X_train_loss, X_test_loss, y_train_loss, y_test_loss = train_test_split(
    home_loss_final_features,
    home_loss_final_target,
    test_size=0.33,
    random_state=1,
)

away_win_y_test_index = y_test_win.index

# Scaling the data
final_feat_scaler = StandardScaler()
X_train_loss = player_feat_scaler.fit_transform(X_train_loss)
X_test_loss = player_feat_scaler.fit_transform(X_test_loss)

# Create and fit the logistic regression model
logit_model_loss = sm.Logit(y_train_loss, sm.add_constant(X_train_loss))
result_loss_final = logit_model_loss.fit_regularized(
    method="l1_cvxopt_cp", alpha=0, disp=0
)

# Predict using the trained model
predictions_loss_final = result_loss_final.predict(sm.add_constant(X_test_loss))

# %% [markdown]
# ##### Classification report:

# %%
print(classification_report(y_test_loss, predictions_loss_final.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.93      0.83      1178
#            1       0.61      0.27      0.38       491
#
#     accuracy                           0.73      1669
#    macro avg       0.68      0.60      0.60      1669
# weighted avg       0.71      0.73      0.70      1669

# %% [markdown]
# ##### Coefficients:

# %%
# | label: tbl-final_coef_away_win
# | tbl-cap: Final home-loss prediction model logistic regression model coefficients.
params_loss_final = result_loss_final.params[1:].to_frame(name="Coefficient")
params_loss_final["p-value"] = result_loss_final.pvalues[1:].values
params_loss_final.index = home_loss_final_features.columns

params_loss_final.sort_values("Coefficient", ascending=True).style.format(
    "{:.3f}"
).applymap(
    lambda value: disf.rb_cell_highlight(value, threshold=significance, higher=False),
    subset="p-value",
)
# Out:
# <style type="text/css">
# #T_739f3_row0_col1, #T_739f3_row1_col1 {
#   background-color: rgba(0, 0, 255, 0.25);
# }
# #T_739f3_row2_col1, #T_739f3_row3_col1, #T_739f3_row4_col1, #T_739f3_row5_col1, #T_739f3_row6_col1, #T_739f3_row7_col1, #T_739f3_row8_col1, #T_739f3_row9_col1, #T_739f3_row10_col1, #T_739f3_row11_col1 {
#   background-color: rgba(255, 0, 0, 0.25);
# }
# </style>
# <table id="T_739f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_739f3_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_739f3_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_739f3_level0_row0" class="row_heading level0 row0" >overall_rating_avg_diff</th>
#       <td id="T_739f3_row0_col0" class="data row0 col0" >-0.568</td>
#       <td id="T_739f3_row0_col1" class="data row0 col1" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row1" class="row_heading level0 row1" >vision_avg_diff</th>
#       <td id="T_739f3_row1_col0" class="data row1 col0" >-0.189</td>
#       <td id="T_739f3_row1_col1" class="data row1 col1" >0.020</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row2" class="row_heading level0 row2" >defencePressure_diff</th>
#       <td id="T_739f3_row2_col0" class="data row2 col0" >-0.078</td>
#       <td id="T_739f3_row2_col1" class="data row2 col1" >0.125</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row3" class="row_heading level0 row3" >finishing_avg_diff</th>
#       <td id="T_739f3_row3_col0" class="data row3 col0" >-0.076</td>
#       <td id="T_739f3_row3_col1" class="data row3 col1" >0.258</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row4" class="row_heading level0 row4" >chanceCreationCrossing_diff</th>
#       <td id="T_739f3_row4_col0" class="data row4 col0" >-0.069</td>
#       <td id="T_739f3_row4_col1" class="data row4 col1" >0.116</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row5" class="row_heading level0 row5" >buildUpPlaySpeed_diff</th>
#       <td id="T_739f3_row5_col0" class="data row5 col0" >-0.007</td>
#       <td id="T_739f3_row5_col1" class="data row5 col1" >0.884</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row6" class="row_heading level0 row6" >buildUpPlayDribbling_diff</th>
#       <td id="T_739f3_row6_col0" class="data row6 col0" >-0.002</td>
#       <td id="T_739f3_row6_col1" class="data row6 col1" >0.957</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row7" class="row_heading level0 row7" >defenceAggression_diff</th>
#       <td id="T_739f3_row7_col0" class="data row7 col0" >0.009</td>
#       <td id="T_739f3_row7_col1" class="data row7 col1" >0.850</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row8" class="row_heading level0 row8" >chanceCreationPassing_diff</th>
#       <td id="T_739f3_row8_col0" class="data row8 col0" >0.011</td>
#       <td id="T_739f3_row8_col1" class="data row8 col1" >0.806</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row9" class="row_heading level0 row9" >buildUpPlayPassing_diff</th>
#       <td id="T_739f3_row9_col0" class="data row9 col0" >0.014</td>
#       <td id="T_739f3_row9_col1" class="data row9 col1" >0.777</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row10" class="row_heading level0 row10" >defenceTeamWidth_diff</th>
#       <td id="T_739f3_row10_col0" class="data row10 col0" >0.022</td>
#       <td id="T_739f3_row10_col1" class="data row10 col1" >0.617</td>
#     </tr>
#     <tr>
#       <th id="T_739f3_level0_row11" class="row_heading level0 row11" >chanceCreationShooting_diff</th>
#       <td id="T_739f3_row11_col0" class="data row11 col0" >0.060</td>
#       <td id="T_739f3_row11_col1" class="data row11 col1" >0.156</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Receiver Operating Characteristic Curve:

# %%
# | label: fig-roc_final_away
# | fig-cap: Receiver operating characteristic curve of the final away-win model
fpr, tpr, thresholds = roc_curve(y_test_loss, predictions_loss_final)
auc_score = roc_auc_score(y_test_loss, predictions_loss_final)

fig_roc_loss, ax_roc_loss = plt.subplots(figsize=(base_fig_width, base_fig_height))
ax_roc_loss.plot(fpr, tpr, label="ROC curve (AUC = %0.2f)" % auc_score)
ax_roc_loss.plot([0, 1], [0, 1], "k--")  # Random guessing line
ax_roc_loss.set_xlabel("False Positive Rate")
ax_roc_loss.set_ylabel("True Positive Rate")
ax_roc_loss.legend(loc="lower right")
plt.show()

# %% [markdown]
# The model that predicts away wins demonstrates a higher accuracy and ROC-AUC compared to the model predicting home wins. However, this improved performance is primarily due to the higher prediction accuracy of negative outcomes, i.e., correctly predicting matches that are not away wins. This is mainly attributed to the fact that away wins are relatively rarer events compared to home wins.
#
# While the overall accuracy may be higher in the away win prediction model, it is essential to consider the precision of positive outcome predictions (away wins). A lower precision in positive predictions implies that there is a higher likelihood of false positives, meaning the model may incorrectly predict away wins more often.
#
# Given that betting profits are contingent on making correct positive outcome predictions, this lower precision may negatively impact potential betting profits. In such cases, even though the overall accuracy is higher, the model's performance might not be favorable for betting strategies.

# %% [markdown]
# ### Win-Loss-Tie Prediction

# %% [markdown]
# Predicting match ties is more complex than determining home or away wins since ties fall between the two extreme outcomes. As a result, the task cannot be simplified into a standard logistic regression problem.
#
# To address this challenge, we will employ several strategies, starting with the use of an ordinal regression model. Ordinal regression is designed to handle situations where the outcomes have a natural ordering, such as in our case where match outcomes can be ranked as home win, tie, or away win. This model allows us to predict multiple ordered outcomes, accommodating the intermediate nature of match ties.

# %% [markdown]
# #### Ordered model

# %%
home_win_final_target = match_win_final_df["w_l_t"]
home_win_final_features = match_win_final_df[
    team_feat_names + rfe_selected_columns.to_list()
]

# Splitting the data into training and test sets
X_train, X_test, y_train_final_class, y_test_final_class = train_test_split(
    home_win_final_features,
    home_win_final_target,
    test_size=0.33,
    random_state=1,
)

# Scaling the data
final_feat_scaler = StandardScaler()
X_train = player_feat_scaler.fit_transform(X_train)
X_test = player_feat_scaler.fit_transform(X_test)

# Create and fit the logistic regression model
ordered_log_model = OrderedModel(y_train_final_class, X_train)
result_multi_logit = ordered_log_model.fit(maxiter=10000)

# Predict using the trained model
predictions_wlt = result_multi_logit.predict(X_test)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.998159
#          Iterations: 2298
#          Function evaluations: 3050

# %% [markdown]
# ##### Classification report:

# %%
print(
    classification_report(
        np.asarray(y_test_final_class.values.codes), predictions_wlt.argmax(1)
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.52      0.50       491
#            1       0.00      0.00      0.00       442
#            2       0.52      0.81      0.63       736
#
#     accuracy                           0.51      1669
#    macro avg       0.33      0.44      0.38      1669
# weighted avg       0.37      0.51      0.43      1669

# %% [markdown]
# The performance of the ordered model, with an overall accuracy of 51%, indicates that it struggled to make correct predictions, particularly when it came to tie matches. The fact that the model did not correctly guess a single tie match suggests that there is considerable overlap between the predictions for home wins and away wins, making it difficult to distinguish the tie matches in between.

# %% [markdown]
# ### Win-loss-tie prediction: Experimental section

# %% [markdown]
# In this section, I explore the possibility of achieving a win-loss-tie classification by leveraging the probabilities obtained from the home-win and away-win models. To achieve this, I modify the rounding function to accommodate a three-outcome classification system. This approach involves setting two thresholds—one for extreme values that determine a home win and another for extreme values that determine a home loss. Probabilities falling between these thresholds will be treated as indicative of a tie outcome.
#
# To implement this approach, I create a function that takes probabilities as input and determines the outcome based on these probabilities and the set thresholds. This function then compares the predicted outcomes with the actual results, generating a boolean residual matrix.
#
# To optimize the threshold values and improve the model's performance, I will use the lmfit library, which allows me to minimize the output of the function. By optimizing the threshold values, I can obtain the best classification accuracy for win-loss-tie predictions.
#
# Once the optimal threshold values are determined, I will apply them to predict the outcomes of the test set.

# %% [markdown]
# #### Custom prediction based on home win and home loss probabilities:

# %% [markdown]
# ##### Calculating win and loss probabilities for the training set:

# %%
predicts_both = pd.DataFrame(
    {
        "win": result_win_final.predict(sm.add_constant(X_train_win)),
        "loss": result_loss_final.predict(sm.add_constant(X_train_loss)),
    }
)

# %% [markdown]
# ##### Initiating threshold parameters and minimizing a function that uses home-win and away-win probability differences:

# %%
params_class_dif = Parameters()
params_class_dif.add("coef_a", value=0.1, min=0.01, max=0.5)
params_class_dif.add("coef_b", value=0.25, min=0.01, max=0.5)
minner_class_dif = Minimizer(
    classifier_train_prob_dif, params_class_dif, fcn_args=(predicts_both, y_train)
)
result_class_dif = minner_class_dif.minimize(method="basinhopping")

# %% [markdown]
# ##### Fit result:

# %%
result_class_dif
# Out:
# <h2>Fit Result</h2> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>basinhopping</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>303</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>3386</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>2</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 3386.00000</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.00059102</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 4.00000000</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 16.2548091</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>coef_a</td><td style='text-align:left'> 0.10000000</td><td style='text-align:left'>0.1</td><td style='text-align:left'> 0.01000000</td><td style='text-align:left'> 0.50000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>coef_b</td><td style='text-align:left'> 0.25000000</td><td style='text-align:left'>0.25</td><td style='text-align:left'> 0.01000000</td><td style='text-align:left'> 0.50000000</td><td style='text-align:right'>True</td></tr></table>

# %% [markdown]
# ##### Predictions and classification report:

# %%
final_predict = pd.DataFrame(
    {"win": predictions_win_final, "loss": predictions_loss_final}
)

final_predict["guess"] = predicts_both.apply(
    outcome_guess_prob_dif,
    axis=1,
    args=(
        result_class_dif.params["coef_a"].value,
        result_class_dif.params["coef_b"].value,
    ),
)

print(classification_report(y_test_final_class, final_predict["guess"]))
# Out:
#               precision    recall  f1-score   support
#
#    Home Loss       0.33      0.15      0.20       491
#     Home Win       0.43      0.56      0.48       736
#          Tie       0.26      0.29      0.27       442
#
#     accuracy                           0.37      1669
#    macro avg       0.34      0.33      0.32      1669
# weighted avg       0.35      0.37      0.35      1669

# %% [markdown]
# #### Custom prediction based on home-win probabilities only

# %% [markdown]
# ##### Initiating the parameters and minimizing the function tha uses only home-win probabilities:

# %%
params_class_hw = Parameters()
params_class_hw.add("coef_win", value=0.1, min=0.1, max=0.5)
params_class_hw.add("coef_loss", value=0.25, min=0.1, max=0.5)
minner_class_hw = Minimizer(
    classifier_train_prob_win, params_class_hw, fcn_args=(predicts_both["win"], y_train)
)
result_class_hw = minner_class_hw.minimize(method="basinhopping")

# %% [markdown]
# ##### Fit result:

# %%
result_class_hw
# Out:
# <h2>Fit Result</h2> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>basinhopping</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>303</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>3386</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>2</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 3386.00000</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.00059102</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 4.00000000</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 16.2548091</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>coef_win</td><td style='text-align:left'> 0.10000000</td><td style='text-align:left'>0.1</td><td style='text-align:left'> 0.10000000</td><td style='text-align:left'> 0.50000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>coef_loss</td><td style='text-align:left'> 0.25000000</td><td style='text-align:left'>0.25</td><td style='text-align:left'> 0.10000000</td><td style='text-align:left'> 0.50000000</td><td style='text-align:right'>True</td></tr></table>

# %% [markdown]
# ##### Predictions and classification report:

# %%
final_pred = pd.Series(predictions_win_final).apply(
    outcome_guess_prob_win,
    args=(
        result_class_hw.params["coef_win"].value,
        result_class_hw.params["coef_loss"].value,
    ),
)

print(classification_report(y_test_final_class, final_pred))
# Out:
#               precision    recall  f1-score   support
#
#    Home Loss       0.61      0.27      0.38       491
#     Home Win       1.00      0.00      0.01       736
#          Tie       0.27      0.89      0.42       442
#
#     accuracy                           0.32      1669
#    macro avg       0.63      0.39      0.27      1669
# weighted avg       0.69      0.32      0.22      1669

# %% [markdown]
# #### Win-loss-tie determination summary

# %% [markdown]
# The best attempt for three-outcome match predictions was achieved by utilizing the probabilities from the home-win model and applying an extra step involving a custom three-way probability rounding function. This pipeline resulted in an accuracy of 48%, which is higher than random for a three-outcome problem. The model demonstrated the ability to identify tie matches with a precision of 0.28, indicating a fair number of correct predictions among the identified ties, which the ordered model failed to achieve completely. However, the recall for tie matches was only 0.07, suggesting that the model missed many actual tie outcomes.
#
# While the results of the model may not be entirely satisfactory, this serves as a proof-of-concept for three-outcome match prediction, demonstrating that it is possible to achieve above-random performance in classifying matches into win, loss, and tie outcomes.
#
# In the future, further improvements to the model can be pursued by exploring different combinations of home-win, home-loss, away-win, and away-loss models.

# %% [markdown]
# ## Player attributes determining the number of goals scored

# %% [markdown]
# In this section, I will use linear regression to identify player attributes that significantly influence the overall number of goals scored by the home team in soccer matches. The primary objective of this analysis is to identify important features rather than predicting match outcomes.

# %% [markdown]
# ### Model building

# %% [markdown]
# ##### Preparing the data for player attributes and the number of goals scored by the home team:

# %%
player_att_dict = {}
for i in match_win_df_player.index:
    player_att_dict[i] = match_win_df_player.at[
        i, "match_players"
    ].export_player_attributes(player_attr_numeric, how="avg")

goals_df = pd.DataFrame.from_dict(player_att_dict, orient="index")

# Dropping rows with missing values
goals_df.dropna(inplace=True)

# In some cases missing attributes were returned as empty dictionaries, dropping these rows
goals_df = goals_df[
    goals_df.apply(
        lambda x: False if dict in [type(i) for i in x.values] else True, axis=1
    )
]

goals_df = goals_df.join(match_raw["home_team_goal"])
goals_df = goals_df.astype(int)

# %% [markdown]
# #### Dropping observationally useless stats

# %% [markdown]
# ##### Dropping overall rating and potential:
# It was already shown that these are the most important attributes and therefore including them would hide the importance of less general player attributes that we want to identify.

# %%
goals_df = goals_df.drop(
    columns=[
        "overall_rating_H_avg",
        "potential_H_avg",
        "overall_rating_A_avg",
        "potential_A_avg",
        "overall_rating_H_gk",
        "potential_H_gk",
        "overall_rating_A_gk",
        "potential_A_gk",
    ]
)

# %% [markdown]
# ##### Regular player goal keeping stats:

# %%
player_gk_stats = [i for i in goals_df.columns if (i[:2] == "gk" and i[-2:] != "gk")]
goals_df = goals_df.drop(columns=player_gk_stats)

# %% [markdown]
# ##### Irrelevant goal keeper attributes:
# Attributes are treated as irrelevant for goal keepers if their average for all goal-keepers is below 30

# %%
irrelevant_gk_stats = (
    goals_df[[i for i in goals_df.columns if i[-2:] == "gk"]]
    .mean()[goals_df[[i for i in goals_df.columns if i[-2:] == "gk"]].mean() < 30]
    .index.to_list()
)

goals_df = goals_df.drop(columns=irrelevant_gk_stats)

# %% [markdown]
# #### Dropping strong linear correlations

# %% [markdown]
# ##### Correlation pairs:

# %%
disf.get_correlation_pairs(goals_df, 0.9, -0.9)
# Out:
#      r-value                                   feature_pair
# 0   0.928173      (short_passing_H_avg, long_passing_H_avg)
# 1   0.946143      (short_passing_H_avg, ball_control_H_avg)
# 2   0.908599         (reactions_H_avg, short_passing_H_avg)
# 3   0.914209          (dribbling_H_avg, ball_control_H_avg)
# 7   0.910845          (reactions_H_avg, ball_control_H_avg)
# 10  0.938733  (sliding_tackle_H_avg, standing_tackle_H_avg)
# 12  0.903585             (gk_reflexes_H_gk, gk_diving_H_gk)
# 14  0.928766      (short_passing_A_avg, long_passing_A_avg)
# 15  0.942833      (ball_control_A_avg, short_passing_A_avg)
# 16  0.908592         (reactions_A_avg, short_passing_A_avg)
# 17  0.910627          (dribbling_A_avg, ball_control_A_avg)
# 21  0.908793          (reactions_A_avg, ball_control_A_avg)
# 24  0.900987         (marking_A_avg, standing_tackle_A_avg)
# 26  0.940536  (sliding_tackle_A_avg, standing_tackle_A_avg)
# 28  0.903934             (gk_reflexes_A_gk, gk_diving_A_gk)

# %% [markdown]
# ##### Dropping correlating feature clusters:
# As determination of the individual feature importance is the goal, more generalized correlating attributes are removed here

# %%
# Cluster 1 summarized by ball_control

# corr_to_drop = [
#     "long_passing_H_avg",
#     "short_passing_H_avg",
#     "reactions_H_avg",
#     "dribbling_H_avg",
#     "long_passing_A_avg",
#     "short_passing_A_avg",
#     "reactions_A_avg",
#     "dribbling_A_avg",
# ]

corr_to_drop = ["ball_control_H_avg", "ball_control_A_avg"]

# Cluster 2 sliding/standing tackles
corr_to_drop.extend(["sliding_tackle_H_avg", "standing_tackle_A_avg"])

# Cluster 3 gk reflexes/diving
corr_to_drop.extend(["gk_diving_H_gk", "gk_diving_A_gk"])

# Cluster 4 short/long passing
corr_to_drop.extend(["short_passing_H_avg", "short_passing_A_avg"])

goals_df = goals_df.drop(columns=corr_to_drop)

# %% [markdown]
# ##### Are there any left?

# %%
disf.get_correlation_pairs(goals_df, 0.9, -0.9)
# Out:
# Empty DataFrame
# Columns: [r-value, feature_pair]
# Index: []

# %% [markdown]
# ##### Model training and predictions:

# %%
# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    goals_df.drop(columns="home_team_goal"),
    goals_df["home_team_goal"],
    test_size=0.33,
    random_state=1,
)

# Scaling the data
team_feat_scaler = StandardScaler()
X_train = team_feat_scaler.fit_transform(X_train)
X_test = team_feat_scaler.fit_transform(X_test)

lin_reg_pre_rfe = LinearRegression()
lin_rfe = RFECV(lin_reg_pre_rfe, step=1, cv=10, min_features_to_select=6)
lin_rfe = lin_rfe.fit(X_train, y_train)

# Create and fit the logistic regression model
goal_model_all = sm.OLS(y_train, sm.add_constant(X_train[:, lin_rfe.support_]))
result_goal_all = goal_model_all.fit()

# Predict using the trained model
predictions_goal_all = result_goal_all.predict(
    sm.add_constant(X_test[:, lin_rfe.support_])
)

# %% [markdown]
# ##### Selected features:

# %%
# | label: tbl-player_features_goal
# | tbl-cap: Coefficients of the linear regression model trained on player attributes that predicts how many goals will the home team score. The most important coefficients were chosen using RFE analysis with cross validation.

params_goal_all = pd.DataFrame(
    {
        "Coefficient": result_goal_all.params[1:].values,
        "p-value": result_goal_all.pvalues[1:].values,
    },
    # index=goals_df.drop(columns="outcome").columns,
    index=goals_df.drop(columns="home_team_goal").columns[lin_rfe.support_],
)

params_goal_all.sort_values(
    "Coefficient", key=lambda x: abs(x), ascending=False
).style.format("{:.3f}").applymap(
    lambda value: disf.rb_cell_highlight(value, threshold=significance, higher=False),
    subset="p-value",
)
# Out:
# <style type="text/css">
# #T_27f73_row0_col1, #T_27f73_row1_col1, #T_27f73_row2_col1, #T_27f73_row3_col1, #T_27f73_row4_col1, #T_27f73_row5_col1 {
#   background-color: rgba(0, 0, 255, 0.25);
# }
# </style>
# <table id="T_27f73">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27f73_level0_col0" class="col_heading level0 col0" >Coefficient</th>
#       <th id="T_27f73_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27f73_level0_row0" class="row_heading level0 row0" >reactions_A_avg</th>
#       <td id="T_27f73_row0_col0" class="data row0 col0" >-0.219</td>
#       <td id="T_27f73_row0_col1" class="data row0 col1" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_27f73_level0_row1" class="row_heading level0 row1" >vision_H_avg</th>
#       <td id="T_27f73_row1_col0" class="data row1 col0" >0.202</td>
#       <td id="T_27f73_row1_col1" class="data row1 col1" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_27f73_level0_row2" class="row_heading level0 row2" >reactions_H_avg</th>
#       <td id="T_27f73_row2_col0" class="data row2 col0" >0.191</td>
#       <td id="T_27f73_row2_col1" class="data row2 col1" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_27f73_level0_row3" class="row_heading level0 row3" >volleys_H_avg</th>
#       <td id="T_27f73_row3_col0" class="data row3 col0" >0.163</td>
#       <td id="T_27f73_row3_col1" class="data row3 col1" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_27f73_level0_row4" class="row_heading level0 row4" >crossing_A_avg</th>
#       <td id="T_27f73_row4_col0" class="data row4 col0" >-0.149</td>
#       <td id="T_27f73_row4_col1" class="data row4 col1" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_27f73_level0_row5" class="row_heading level0 row5" >gk_handling_A_gk</th>
#       <td id="T_27f73_row5_col0" class="data row5 col0" >-0.106</td>
#       <td id="T_27f73_row5_col1" class="data row5 col1" >0.001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Model validity

# %% [markdown]
# #### R-squared

# %%
result_goal_all.rsquared.round(2)
# Out:
# 0.14

# %% [markdown]
# #### Distribution of residuals

# %%
# | label: fig-line_residuals
# | fig-cap: Residual plot of the player-attribute - home goal linear regression model.
fig_line_resids, (ax_line_resid_hist, ax_resid_qq) = plt.subplots(
    1, 2, figsize=(base_fig_width, base_fig_height)
)
sns.histplot(result_goal_all.resid, ax=ax_line_resid_hist)
sm.qqplot(result_goal_all.resid, line="45", ax=ax_resid_qq)
plt.show()

# %% [markdown]
# #### Linearity of home goals and the most important feature

# %%
# | label: fig-line_scat
# | fig-cap: An illustrative plot of average home team Vision dependance on the number of goals scored by the home teams. 500 random sample matches were taken for the plot.
fig_line_scat, ax_line_scat = plt.subplots(figsize=(base_fig_width, base_fig_height))
sns.regplot(
    data=goals_df.sample(500, random_state=1),
    x="reactions_A_avg",
    y="home_team_goal",
    ax=ax_line_scat,
    scatter_kws={"alpha": 0.3},
)
disf.axis_titles(
    ax_line_scat, "Average Home Team Player Vision", "Number of Home Team Goals"
)

# %% [markdown]
# #### Homoscedasticity. Fitted values vs. residuals plot:

# %%
# | label: fig-line_homosced
# | fig-cap: Relationship between fitted values of the linear regression model and the residuals of the model.
fig_line_homosced, ax_line_homosced = plt.subplots(
    figsize=(base_fig_width, base_fig_height)
)
ax_line_homosced.scatter(result_goal_all.fittedvalues, result_goal_all.resid)
ax_line_homosced.axhline(y=0, color="r", linestyle="--")
disf.axis_titles(ax_line_homosced, "Fitted Values", "Residuals")

# %% [markdown]
# #### Model results and validity summary

# %% [markdown]
# The linear regression analysis with Recursive Feature Elimination (RFE) has provided valuable insights into the important player attributes influencing the number of goals scored by the home team. The results indicate that the most crucial attribute for predicting home team goal scoring is the Away teams player reactions. This suggests that the responsiveness and adaptability of the away team players have a significant impact on limiting the home team's goal scoring opportunities.
#
# Following this, attributes such as vision, reactions, and volleys of the home team players were also found to be important contributors to home team goal scoring. Additionally, crossing ability of the away team and the handling capabilities of the away team's goalkeeper emerged as significant factors affecting the home team's goal scoring performance.
#
# Despite the significance of these features, it is important to note that the overall model performance was poor, with a relatively low R-squared value of 0.14. This indicates that the linear regression model does not explain a substantial portion of the variance in home team goal scoring, suggesting that other factors may play a significant role in determining goal outcomes.
#
# Moreover, the analysis revealed that the model did not meet some of the main assumptions of linear regression. Homoscedasticity, the assumption of constant variance of residuals across the predictor variables, was violated (@fig-line_homosced). Additionally, the residual distribution displayed right-skewness, indicating non-normality (@fig-line_residuals).
#
# Due to these limitations, the results of the linear regression analysis should be interpreted with caution.

# %% [markdown]
# ## Summary

# %% [markdown]
# During this project, logistic regression models and custom probability rounding functions were utilized to construct models capable of predicting home team wins, away team wins, and tie outcomes in soccer matches. The dataset also includes the betting coefficients offered by popular betting companies. This means that not only the accuracy and precision of our models determine betting profits, but also how well the models predict outcomes of games with higher betting odds. Matches with higher betting odds typically indicate more uncertain or unexpected outcomes, and successfully predicting such matches can lead to higher profit potential.
#
# To test the effectiveness of our models, we will employ three different betting strategies:
#
# 1. Betting on home wins based on the home win model.
# 2. Betting on away wins based on the away win model.
# 3. Betting on ties based on the three-outcome prediction model.
#
# In each of these strategies, I will place a bet of 100 currency units if the corresponding model predicts a positive outcome (e.g., home team win, away team win, or tie). This will allow me to compare the performance of our models against the average betting company odds and evaluate the profitability of each strategy.
#
# By assessing the results of these betting strategies, I can determine the effectiveness of the models in generating betting profits, especially when predicting matches with higher betting odds.

# %% [markdown]
# ### Profit Test

# %% [markdown]
# ##### Preparing the betting odd, outcome and prediction data:

# %%
# Names of betting odd columns
away_win_coff_cols = [i for i in match_raw.columns if (len(i) == 3 and i[-1] == "A")]
home_win_coff_cols = [i for i in match_raw.columns if (len(i) == 3 and i[-1] == "H")]
tie_coff_cols = [i for i in match_raw.columns if (len(i) == 3 and i[-1] == "D")]

betting_df = match_raw.iloc[home_win_y_test_index][
    away_win_coff_cols + home_win_coff_cols + tie_coff_cols
].apply(pd.to_numeric)

# Outcomes
betting_df["outcome"] = y_test_final_class.values

# Betting odd averages
betting_df["away_win_coef"] = betting_df[away_win_coff_cols].mean(axis=1)
betting_df["home_win_coef"] = betting_df[home_win_coff_cols].mean(axis=1)
betting_df["tie_coef"] = betting_df[tie_coff_cols].mean(axis=1)

# Model predictions
betting_df["home_win_pred"] = predictions_win_final.round()
betting_df["away_win_pred"] = predictions_loss_final.round()
betting_df["tie_pred"] = final_pred.values

# %% [markdown]
# ##### Applying betting strategies:

# %%
betting_df["home_win_profits"] = betting_df.apply(bet_home, axis=1)
betting_df["away_win_profits"] = betting_df.apply(bet_away, axis=1)
betting_df["tie_profits"] = betting_df.apply(bet_tie, axis=1)

# %% [markdown]
# ### Test results

# %% [markdown]
# ##### Total profits

# %%
# | label: tbl-profit
# | tbl-cap: Summary of profits gained using the three betting strategies based on three different models.

total_profits = (
    betting_df[["home_win_profits", "away_win_profits", "tie_profits"]]
    .sum()
    .to_frame("Total Profits")
)

total_profits["Matches with bets"] = [
    len(betting_df[betting_df["home_win_profits"] != 0]),
    len(betting_df[betting_df["away_win_profits"] != 0]),
    len(betting_df[betting_df["tie_profits"] != 0]),
]
total_profits["Profit per Match"] = (
    total_profits["Total Profits"] / total_profits["Matches with bets"]
)

total_profits.style.format({"Profit per Match": "{:.1f}", "Total Profits": "{:.0f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_361b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_361b3_level0_col0" class="col_heading level0 col0" >Total Profits</th>
#       <th id="T_361b3_level0_col1" class="col_heading level0 col1" >Matches with bets</th>
#       <th id="T_361b3_level0_col2" class="col_heading level0 col2" >Profit per Match</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_361b3_level0_row0" class="row_heading level0 row0" >home_win_profits</th>
#       <td id="T_361b3_row0_col0" class="data row0 col0" >70519</td>
#       <td id="T_361b3_row0_col1" class="data row0 col1" >592</td>
#       <td id="T_361b3_row0_col2" class="data row0 col2" >119.1</td>
#     </tr>
#     <tr>
#       <th id="T_361b3_level0_row1" class="row_heading level0 row1" >away_win_profits</th>
#       <td id="T_361b3_row1_col0" class="data row1 col0" >60274</td>
#       <td id="T_361b3_row1_col1" class="data row1 col1" >221</td>
#       <td id="T_361b3_row1_col2" class="data row1 col2" >272.7</td>
#     </tr>
#     <tr>
#       <th id="T_361b3_level0_row2" class="row_heading level0 row2" >tie_profits</th>
#       <td id="T_361b3_row2_col0" class="data row2 col0" >35983</td>
#       <td id="T_361b3_row2_col1" class="data row2 col1" >1446</td>
#       <td id="T_361b3_row2_col2" class="data row2 col2" >24.9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The profit test results indicate that the home win model was the most profitable in terms of total profits. However, it's noteworthy that the away win model's profitability per match was more than twice that of the home win model. This difference in profitability can likely be attributed to the fact that away win outcomes are rarer in soccer matches, leading to higher betting odds when they do occur. As a result, successful predictions of away wins can yield larger profits per match compared to home wins.
#
# On the other hand, the Tie model was the least profitable among the three strategies, but it still managed to generate positive profits. Although tie outcomes are less common and thus have higher betting odds, accurately predicting ties remains challenging due to their intermediate nature between home and away wins. Nevertheless, the model's ability to achieve positive profits indicates some level of success in identifying tie outcomes.

# %% [markdown]
# ### Conclusions

# %% [markdown]
# * Logistic regression effectively predicts home and away team wins, enabling profitable betting strategies.
# * Custom probability rounding functions applied to logistic regression results allow detection of tie matches.
# * The linear regression model did not provide reliable insights on player attributes contributing to total goals scored by the home team.
